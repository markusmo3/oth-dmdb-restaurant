# %% [markdown]
# Basics

# %%
import pandas as pd

data = pd.read_csv('/data/restaurants.tsv', delimiter='\t')
data.head(50)
# Out:
#     id                                   name                  address  \
# 0    1              arnie morton's of chicago   435 s. la cienega blv.
# 1    2              arnie morton's of chicago  435 s. la cienega blvd.
# 2    3                     art's delicatessen      12224 ventura blvd.
# 3    4                             art's deli      12224 ventura blvd.
# 4    5                          hotel bel-air     701 stone canyon rd.
# 5    6                          bel-air hotel     701 stone canyon rd.
# 6    7                             cafe bizou      14016 ventura blvd.
# 7    8                             cafe bizou      14016 ventura blvd.
# 8    9                              campanile      624 s. la brea ave.
# 9   10                              campanile      624 s. la brea ave.
# 10  11                        chinois on main            2709 main st.
# 11  12                        chinois on main            2709 main st.
# 12  13                                 citrus        6703 melrose ave.
# 13  14                                 citrus        6703 melrose ave.
# 14  15                                  fenix   8358 sunset blvd. west
# 15  16                    fenix at the argyle        8358 sunset blvd.
# 16  17                                granita      23725 w. malibu rd.
# 17  18                                granita      23725 w. malibu rd.
# 18  19                     grill on the alley          9560 dayton way
# 19  20                             grill  the          9560 dayton way
# 20  21                       restaurant katsu   1972 n. hillhurst ave.
# 21  22                                  katsu      1972 hillhurst ave.
# 22  23                            l'orangerie  903 n. la cienega blvd.
# 23  24                            l'orangerie  903 n. la cienega blvd.
# 24  25                          le chardonnay        8284 melrose ave.
# 25  26            le chardonnay (los angeles)        8284 melrose ave.
# 26  27                         locanda veneta                  3rd st.
# 27  28                         locanda veneta        8638 w. third st.
# 28  29                              matsuhisa  129 n. la cienega blvd.
# 29  30                              matsuhisa  129 n. la cienega blvd.
# 30  31                               the palm  9001 santa monica blvd.
# 31  32                palm  the (los angeles)  9001 santa monica blvd.
# 32  33                                 patina        5955 melrose ave.
# 33  34                                 patina        5955 melrose ave.
# 34  35                philippe's the original      1001 n. alameda st.
# 35  36                  philippe the original      1001 n. alameda st.
# 36  37                           pinot bistro      12969 ventura blvd.
# 37  38                           pinot bistro      12969 ventura blvd.
# 38  39                      rex il ristorante         617 s. olive st.
# 39  40                      rex il ristorante         617 s. olive st.
# 40  41                                  spago           1114 horn ave.
# 41  42                    spago (los angeles)        8795 sunset blvd.
# 42  43                              valentino          3115 pico blvd.
# 43  44                              valentino          3115 pico blvd.
# 44  45  yujean kang's gourmet chinese cuisine       67 n. raymond ave.
# 45  46                          yujean kang's       67 n. raymond ave.
# 46  47                                21 club           21 w. 52nd st.
# 47  48                                21 club           21 w. 52nd st.
# 48  49                                aquavit           13 w. 54th st.
# 49  50                                aquavit           13 w. 54th st.
#
#              city         phone                    type
# 0     los angeles  310/246-1501                american
# 1     los angeles  310-246-1501             steakhouses
# 2     studio city  818/762-1221                american
# 3     studio city  818-762-1221                   delis
# 4         bel air  310/472-1211             californian
# 5         bel air  310-472-1211             californian
# 6    sherman oaks  818/788-3536                  french
# 7    sherman oaks  818-788-3536           french bistro
# 8     los angeles  213/938-1447                american
# 9     los angeles  213-938-1447             californian
# 10   santa monica  310/392-9025                  french
# 11   santa monica  310-392-9025        pacific new wave
# 12    los angeles  213/857-0034             californian
# 13    los angeles  213-857-0034             californian
# 14      hollywood  213/848-6677                american
# 15   w. hollywood  213-848-6677            french (new)
# 16         malibu  310/456-0488             californian
# 17         malibu  310-456-0488             californian
# 18    los angeles  310/276-0615                american
# 19  beverly hills  310-276-0615  american (traditional)
# 20    los angeles  213/665-1891                   asian
# 21      los feliz  213-665-1891                japanese
# 22    los angeles  310/652-9770                  french
# 23   w. hollywood  310-652-9770        french (classic)
# 24    los angeles  213/655-8880                  french
# 25    los angeles  213-655-8880           french bistro
# 26    los angeles  310/274-1893                 italian
# 27    los angeles  310-274-1893                 italian
# 28  beverly hills  310/659-9639                   asian
# 29  beverly hills  310-659-9639                 seafood
# 30    los angeles  310/550-8811                american
# 31   w. hollywood  310-550-8811             steakhouses
# 32    los angeles  213/467-1108             californian
# 33    los angeles  213-467-1108             californian
# 34    los angeles  213/628-3781                american
# 35      chinatown  213-628-3781              cafeterias
# 36    los angeles  818/990-0500                  french
# 37    studio city  818-990-0500           french bistro
# 38    los angeles  213/627-2300                 italian
# 39    los angeles  213-627-2300    nuova cucina italian
# 40    los angeles  310/652-4025             californian
# 41   w. hollywood  310-652-4025             californian
# 42   santa monica  310/829-4313                 italian
# 43   santa monica  310-829-4313                 italian
# 44    los angeles  818/585-0855                   asian
# 45       pasadena  818-585-0855                 chinese
# 46       new york  212/582-7200                american
# 47  new york city  212-582-7200          american (new)
# 48       new york  212/307-7311             continental
# 49  new york city  212-307-7311            scandinavian

# %%
data.describe()
# Out:
#                id
# count  864.000000
# mean   432.500000
# std    249.559612
# min      1.000000
# 25%    216.750000
# 50%    432.500000
# 75%    648.250000
# max    864.000000

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 864 entries, 0 to 863
# Data columns (total 6 columns):
# id         864 non-null int64
# name       864 non-null object
# address    864 non-null object
# city       864 non-null object
# phone      864 non-null object
# type       863 non-null object
# dtypes: int64(1), object(5)
# memory usage: 40.6+ KB

# %%
unique_addresses = data.address.unique()
token_count = {}
for a in unique_addresses:
    tokens = a.split(' ')
    for t in tokens:
        if t not in token_count:
            token_count[t] = 1
        else:
            token_count[t] += 1

for key, value in sorted(token_count.items(), key=lambda item: item[1]):
    print("%s: %s" % (key, value))
# Out:
# blv.: 1
# 12224: 1
# 701: 1
# stone: 1
# canyon: 1
# 14016: 1
# 624: 1
# 2709: 1
# 6703: 1
# 23725: 1
# malibu: 1
# 9560: 1
# dayton: 1
# 903: 1
# 8284: 1
# 8638: 1
# 9001: 1
# 5955: 1
# 1001: 1
# alameda: 1
# 12969: 1
# 617: 1
# 1114: 1
# horn: 1
# 8795: 1
# 3115: 1
# 67: 1
# raymond: 1
# 90th: 1
# 91st: 1
# 99: 1
# 12: 1
# 249: 1
# 15th: 1
# walker: 1
# 182: 1
# 35: 1
# rockefeller: 1
# river: 1
# 11: 1
# 43: 1
# 797: 1
# 2245: 1
# neiman: 1
# 1529: 1
# margaret: 1
# mitchell: 1
# rio: 1
# 1397: 1
# house: 1
# harris: 1
# 1232: 1
# 293-b: 1
# 41: 1
# la.: 1
# ln.: 1
# northpoint: 1
# point: 1
# 777: 1
# 22: 1
# hawthorne: 1
# 5937: 1
# 2316: 1
# 816: 1
# 648: 1
# 1737: 1
# 3201: 1
# 3127: 1
# 545: 1
# 532: 1
# 2930: 1
# glen: 1
# 9570: 1
# 26025: 1
# 176: 1
# canon: 1
# 346: 1
# 4100: 1
# cahuenga: 1
# 207: 1
# 419: 1
# 656: 1
# virgil: 1
# larchmont: 1
# 9500: 1
# 10250: 1
# 2628: 1
# 730: 1
# 930: 1
# hilgard: 1
# 8800: 1
# 134: 1
# 1121: 1
# western: 1
# 2424: 1
# fish: 1
# 17300: 1
# 8600: 1
# 2020: 1
# stars: 1
# 10668: 1
# drive: 1
# moreno: 1
# 9255: 1
# 8783: 1
# 8720: 1
# 4500: 1
# los: 1
# feliz: 1
# 679: 1
# 8764: 1
# 414: 1
# 1401: 1
# 11705: 1
# 10001: 1
# riverside: 1
# 1448: 1
# 14928: 1
# 362: 1
# pedro: 1
# 1514: 1
# 3110: 1
# 8020: 1
# 7371: 1
# 7313: 1
# 3835: 1
# cross: 1
# creek: 1
# 9876: 1
# 1930: 1
# venice: 1
# 14: 1
# 937: 1
# 304: 1
# 311: 1
# united: 1
# nations: 1
# 200-250: 1
# vesey: 1
# 321: 1
# 123: 1
# 21st: 1
# 948: 1
# 1393a: 1
# 73rd: 1
# 420: 1
# 59th: 1
# varick: 1
# clarkston: 1
# waverly: 1
# 1486: 1
# 69: 1
# 70th: 1
# vanderbilt: 1
# charles: 1
# 81: 1
# bleeker: 1
# 169: 1
# sullivan: 1
# 119: 1
# 385: 1
# 451: 1
# watts: 1
# 860: 1
# 72: 1
# 1013: 1
# 39th: 1
# 164: 1
# 121: 1
# 341: 1
# 633: 1
# duane: 1
# 1325: 1
# 111th: 1
# 2150: 1
# 1288: 1
# 69th: 1
# desbrosses: 1
# 29: 1
# 635: 1
# 1900: 1
# 73: 1
# 348: 1
# pearl: 1
# broad: 1
# 458: 1
# 2340: 1
# 43rd: 1
# 467: 1
# 685: 1
# 93rd: 1
# 208: 1
# catherine: 1
# rihga: 1
# royal: 1
# hotel: 1
# 1340: 1
# cornelia: 1
# 125: 1
# 251: 1
# 492: 1
# 82: 1
# 326: 1
# 227: 1
# 1191: 1
# bank: 1
# 361: 1
# 211: 1
# 149: 1
# cleveland: 1
# 507: 1
# 84th: 1
# 51: 1
# 59: 1
# 2182: 1
# 446: 1
# 1161: 1
# 325: 1
# university: 1
# 1030: 1
# 23rd: 1
# 104: 1
# 19th: 1
# thomas: 1
# 142: 1
# 138: 1
# 51st.: 1
# 1065: 1
# 24: 1
# 250: 1
# 109: 1
# 1423: 1
# 140: 1
# 371: 1
# 87th: 1
# 37a: 1
# w: 1
# 1063: 1
# 148: 1
# chrystie: 1
# delancey: 1
# 1000: 1
# 643: 1
# 66th: 1
# 58: 1
# 62: 1
# 834: 1
# 428: 1
# 76: 1
# 143: 1
# 65: 1
# 950: 1
# 119th: 1
# morningside: 1
# 350: 1
# 2420: 1
# 89th: 1
# 900: 1
# 345: 1
# 154: 1
# 386: 1
# 52: 1
# 236: 1
# 68th: 1
# 30th: 1
# steakhouse: 1
# 174: 1
# e: 1
# 90: 1
# 163: 1
# 783: 1
# martin: 1
# luther: 1
# king: 1
# jr.: 1
# 3195: 1
# 3109: 1
# just: 1
# 265: 1
# 260: 1
# phipps: 1
# 1100: 1
# 7050: 1
# 1186: 1
# hyatt: 1
# hurt: 1
# 40: 1
# crossing: 1
# on: 1
# sidney: 1
# 1879: 1
# 3380: 1
# atlanta: 1
# 1811: 1
# 6359: 1
# 4320: 1
# 192: 1
# international: 1
# 2285: 1
# holiday: 1
# inn/crowne: 1
# ravinia: 1
# c: 1
# northwoods: 1
# doraville: 1
# 6301: 1
# 1931: 1
# 1402: 1
# 3209: 1
# maple: 1
# place: 1
# across: 1
# from: 1
# perimeter: 1
# 247: 1
# village: 1
# 1829: 1
# 555: 1
# linden: 1
# 870: 1
# irby: 1
# 3043: 1
# 6050: 1
# 1144: 1
# crescent: 1
# 2345: 1
# 3384: 1
# shallowford: 1
# chamblee: 1
# 2165: 1
# 889: 1
# 4850: 1
# 4041: 1
# audrie: 1
# 4111: 1
# 3555: 1
# 1350: 1
# 3333: 1
# maryland: 1
# 2411: 1
# 1510: 1
# 3120: 1
# 5111: 1
# 3713: 1
# 6182: 1
# 3900: 1
# 2223: 1
# 1722: 1
# o'farrell: 1
# 2030: 1
# gold: 1
# 598: 1
# 3347: 1
# 2317: 1
# 625: 1
# 1600: 1
# 1772: 1
# jackson: 1
# 732: 1
# 1300: 1
# ghirardelli: 1
# 501: 1
# bldg.: 1
# fort: 1
# mason: 1
# embarcadero: 1
# 2100: 1
# 320: 1
# 5322: 1
# 2332: 1
# 1521: 1
# 1265: 1
# 615: 1
# 5116: 1
# 453: 1
# 607: 1
# 3226: 1
# 470: 1
# mcallister: 1
# 1652: 1
# 3131: 1
# webster: 1
# 1915: 1
# 640: 1
# 3011: 1
# 1015: 1
# 1944: 1
# kearny: 1
# 558: 1
# tillman: 1
# 1702: 1
# 108: 1
# redwood: 1
# alley: 1
# 1240: 1
# 3235: 1
# 298: 1
# gough: 1
# 3148: 1
# 2125: 1
# 670: 1
# golden: 1
# gate: 1
# 2257: 1
# 101: 1
# spear: 1
# 427: 1
# 1220: 1
# 1611: 1
# 2000: 1
# 1658: 1
# 10801: 1
# 2027: 1
# sawtelle: 1
# kimber: 1
# 9882: 1
# 1433: 1
# mentor: 1
# 19565: 1
# parthenia: 1
# 9600: 1
# brighton: 1
# 1570: 1
# rosecrans: 1
# 3838: 1
# centinela: 1
# 838: 1
# lincoln: 1
# 9777: 1
# 3266: 1
# 1716: 1
# 1020: 1
# 1136: 1
# 8909: 1
# 1059: 1
# broxton: 1
# 1949: 1
# 6333: 1
# 6145: 1
# 10428: 1
# 8424: 1
# 502: 1
# blvd: 1
# 2011: 1
# walk: 1
# 1023: 1
# abbot: 1
# kinney: 1
# 10516: 1
# 4017: 1
# sepulveda: 1
# 4663: 1
# long: 1
# beach: 1
# 7507: 1
# 4000: 1
# colfax: 1
# 8393: 1
# 10506: 1
# 22800: 1
# 1842: 1
# 704: 1
# alvarado: 1
# 30869: 1
# thousand: 1
# 10509: 1
# grill: 1
# 13329: 1
# 1147: 1
# 8474: 1
# 7261: 1
# 17040: 1
# 3117: 1
# 875: 1
# downtown: 1
# 510: 1
# arroyo: 1
# 642: 1
# 709: 1
# 2635: 1
# 2901: 1
# 15322: 1
# fair: 1
# 1198: 1
# 1505: 1
# 11288: 1
# 8360: 1
# 11677: 1
# 2575: 1
# 1305: 1
# 544: 1
# 1415: 1
# 424: 1
# 331: 1
# 368: 1
# 47th: 1
# 24-02: 1
# 31st: 1
# 483: 1
# 2090: 1
# 86: 1
# 37-03: 1
# 48: 1
# 127: 1
# 117: 1
# 2199: 1
# 61a: 1
# 466: 1
# 296: 1
# 105: 1
# 17: 1
# barrow: 1
# lower: 1
# level: 1
# 837: 1
# 840: 1
# 178: 1
# 1295: 1
# 5-16: 1
# 38: 1
# 328: 1
# 1588: 1
# york: 1
# 1460: 1
# 80: 1
# montague: 1
# 144: 1
# 689: 1
# 107th: 1
# 953: 1
# 401: 1
# 202: 1
# 4750: 1
# 3595: 1
# 3145: 1
# 3925: 1
# 355: 1
# convention: 1
# 659: 1
# euclid: 1
# 1437: 1
# virginia: 1
# andrews: 1
# 2911: 1
# court: 1
# 4274: 1
# 5975: 1
# 4199: 1
# 1021: 1
# 1215: 1
# 4279: 1
# 1029: 1
# edgewood: 1
# 1655: 1
# mclendon: 1
# 1087: 1
# 171: 1
# mcdonough: 1
# 2905: 1
# 2469: 1
# 3675: 1
# satellite: 1
# 790: 1
# 2970: 1
# 1248: 1
# clairmont: 1
# 4427: 1
# 3525: 1
# 303: 1
# 3060: 1
# 1495: 1
# chattahoochee: 1
# 4330: 1
# 3391: 1
# 2118: 1
# decatur: 1
# 3330: 1
# marietta: 1
# 774: 1
# crossville: 1
# 220: 1
# 3172: 1
# 4837: 1
# 2315: 1
# 2298: 1
# 1805: 1
# haight: 1
# 2217: 1
# 3221: 1
# 1283: 1
# 1550: 1
# 1500: 1
# church: 1
# 1582: 1
# 333: 1
# 288: 1
# noe: 1
# 2889: 1
# 2209: 1
# 2225: 1
# 3355: 1
# 1322: 1
# grant: 1
# larkin: 1
# 2817: 1
# 300: 1
# haro: 1
# 1328: 1
# 584: 1
# 1517: 1
# waller: 1
# 3108: 1
# 1870: 1
# 8: 1
# ivy: 1
# 2141: 1
# 8358: 2
# way: 2
# 1972: 2
# 2450: 2
# 854: 2
# seventh: 2
# harrison: 2
# 76th: 2
# 210: 2
# 243: 2
# 42: 2
# 402: 2
# 33: 2
# 102: 2
# fifth: 2
# jane: 2
# 239: 2
# white: 2
# 55: 2
# 100: 2
# 95: 2
# 30: 2
# water: 2
# east: 2
# 156: 2
# 1110: 2
# in: 2
# 747: 2
# 152: 2
# 3200: 2
# 3799: 2
# 3570: 2
# 2880: 2
# 2355: 2
# battle: 2
# 3125: 2
# 3130: 2
# 3393: 2
# lenox: 2
# square: 2
# marcus: 2
# 3073: 2
# 2290: 2
# 490: 2
# 595: 2
# 2637: 2
# condominium: 2
# 224: 2
# 255: 2
# courtland: 2
# 3434: 2
# 181: 2
# b: 2
# 126: 2
# 252: 2
# claude: 2
# 340: 2
# 804: 2
# north: 2
# sutter: 2
# 570: 2
# folsom: 2
# circle: 2
# pacific: 2
# coast: 2
# promenade: 2
# 700: 2
# fairfax: 2
# 310: 2
# colorado: 2
# of: 2
# 301: 2
# 439: 2
# 601: 2
# figueroa: 2
# gower: 2
# camden: 2
# 111: 2
# mott: 2
# bowery: 2
# pell: 2
# 9: 2
# 322: 2
# 222: 2
# 206: 2
# thompson: 2
# world: 2
# financial: 2
# 1022: 2
# 23: 2
# 72nd: 2
# 225: 2
# 40th: 2
# 71st: 2
# 246: 2
# 46: 2
# wooster: 2
# 120: 2
# 157: 2
# 219: 2
# 6: 2
# 39: 2
# 86th: 2
# 87: 2
# 24th: 2
# 54: 2
# fulton: 2
# 93: 2
# 18: 2
# 221: 2
# 122: 2
# 27th: 2
# hester: 2
# astor: 2
# 68: 2
# 50: 2
# 18th: 2
# 411: 2
# 28th: 2
# 29th: 2
# 800: 2
# 342: 2
# 1134: 2
# 551: 2
# 28: 2
# 1/2: 2
# bayard: 2
# howard: 2
# 205: 2
# greene: 2
# 133: 2
# 423: 2
# 80th: 2
# 19: 2
# 3: 2
# 375: 2
# street: 2
# 44: 2
# south: 2
# 3500: 2
# jimmy: 2
# carter: 2
# buckhead: 2
# 923: 2
# powers: 2
# dunwoody: 2
# 3700: 2
# 3645: 2
# 128: 2
# 3400: 2
# boulder: 2
# 308: 2
# steuart: 2
# 56: 2
# chestnut: 2
# 161: 2
# new: 2
# van: 2
# ness: 2
# hayes: 2
# hyde: 2
# 3345: 2
# steiner: 2
# front: 2
# green: 2
# 631: 2
# 515: 2
# vicente: 2
# westwood: 2
# first: 2
# oaks: 2
# atlantic: 2
# 764: 2
# fl.: 2
# old: 2
# se: 2
# 1031: 2
# valencia: 2
# 435: 3
# brea: 3
# hillhurst: 3
# 129: 3
# olive: 3
# 13: 3
# 34: 3
# 83rd: 3
# 67th: 3
# 20: 3
# 12th: 3
# 50th: 3
# 405: 3
# 3000: 3
# shopping: 3
# road: 3
# california: 3
# 7: 3
# stockton: 3
# bush: 3
# 168: 3
# ocean: 3
# national: 3
# san: 3
# 430: 3
# jones: 3
# 48th: 3
# 32nd: 3
# 106: 3
# 8th: 3
# 103: 3
# washington: 3
# lexington: 3
# 77th: 3
# 78th: 3
# greenwich: 3
# 32: 3
# 150: 3
# 45: 3
# 74th: 3
# 522: 3
# 75th: 3
# 85th: 3
# 62nd: 3
# 82nd: 3
# 15: 3
# 151: 3
# canal: 3
# 432: 3
# 145: 3
# irving: 3
# madison: 3
# 79th: 3
# 400: 3
# 70: 3
# pharr: 3
# norcross: 3
# 3300: 3
# underground: 3
# sandy: 3
# springs: 3
# powell: 3
# montgomery: 3
# 519: 3
# little: 3
# pch: 3
# cobb: 3
# main: 4
# 21: 4
# 201: 4
# 20th: 4
# 160: 4
# 155: 4
# the: 4
# 10th: 4
# ninth: 4
# paradise: 4
# 14th: 4
# clement: 4
# fourth: 4
# 600: 4
# wilshire: 4
# 60th: 4
# 228: 4
# 25: 4
# 45th: 4
# macdougal: 4
# broome: 4
# mulberry: 4
# franklin: 4
# 11th: 4
# lafayette: 4
# 81st: 4
# 56th: 4
# cheshire: 4
# bridge: 4
# buford: 4
# battery: 4
# sixth: 4
# nw: 4
# west: 5
# 61st: 5
# 7th: 5
# 60: 5
# central: 5
# 57: 5
# 16th: 5
# off: 5
# a: 5
# 240: 5
# 200: 5
# highland: 5
# mission: 5
# polk: 5
# post: 5
# 4: 5
# spring: 5
# 17th: 5
# mercer: 5
# union: 5
# 500: 5
# roswell: 5
# sahara: 5
# sacramento: 5
# cienega: 6
# santa: 6
# monica: 6
# pico: 6
# hudson: 6
# 64th: 6
# second: 6
# 65th: 6
# 49th: 6
# fremont: 6
# mall: 6
# sq.: 6
# ponce: 6
# leon: 6
# fillmore: 6
# prince: 6
# pkwy.: 6
# ventura: 7
# sunset: 7
# 2: 7
# 44th: 7
# 51st: 7
# 63rd: 7
# plaza: 7
# center: 7
# de: 7
# 4th: 7
# geary: 7
# 22nd: 7
# houston: 7
# 57th: 7
# market: 7
# 54th: 8
# 53rd: 8
# flamingo: 8
# paces: 8
# columbus: 8
# pl.: 8
# bleecker: 8
# grand: 8
# amsterdam: 8
# la: 9
# 52nd: 9
# 1: 9
# 55th: 9
# 9th: 9
# hwy.: 9
# melrose: 10
# third: 10
# ne: 10
# ferry: 10
# 46th: 10
# 58th: 12
# 5th: 12
# 6th: 12
# piedmont: 12
# aves.: 12
# beverly: 13
# 2nd: 14
# 3rd: 15
# s: 15
# dr.: 15
# near: 16
# park: 17
# las: 19
# vegas: 19
# 1st: 21
# broadway: 27
# n.: 29
# s.: 35
# peachtree: 39
# at: 53
# sts.: 57
# rd.: 69
# between: 79
# and: 81
# e.: 86
# blvd.: 90
# w.: 112
# : 132
# ave.: 175
# st.: 415

# %%
def printuniques(series):
    l = series.unique()
    l.sort()
    print("### " + series.name)
    print(l)

# %%
printuniques(data.name)
printuniques(data.city)
#printuniques(data.phone)
#printuniques(data["type"])
# Out:
# ### name
# ['103 west' '20 mott' '21 club' '2223' '9 jones street' 'abbey' 'abruzzi'
#  'acquarello' "adriano's ristorante" 'adrienne' 'afghan kebab house'
#  'agrotikon' 'aja' 'alain rondelli' 'alamo' "aleck's barbecue heaven"
#  "alley's end" "alon's at the terrace" 'ambassador grill' 'american place'
#  'anche vivolo' "andre's french restaurant" "annie's thai castle"
#  'anthonys' "antonio's" 'apple pan  the' 'aqua' 'aquavit' 'arcadia'
#  'arizona' "arnie morton's of chicago" "art's deli" "art's delicatessen"
#  "arturo's" 'asahi ramen' 'atlanta fish market' 'au mandarin' 'aureole'
#  'bacchanalia' 'baja fresh' "baker's cajun cafe" "bally's big kitchen"
#  'bamboo garden' 'bar anise' 'barbecue kitchen' 'barbetta' "bardelli's"
#  'barney greengrass' "battista's hole in the wall" 'beaurivage'
#  "beesley's of buckhead" 'bel-air hotel' 'belvedere  the' "ben benson's"
#  "benita's frites" "benny's burritos" "bernard's" "bertolini's" 'betelnut'
#  'big cup' "bill's place" "billy's" "binion's coffee shop" 'bistango'
#  'bistro' 'bistro  the' 'bistro 45' 'bistro garden' 'bistro roti' 'bix'
#  'bizou' "bobby & june's kountry kitchen" 'boca chica' 'bolo' "bone's"
#  "bone's restaurant" 'boonthai' 'border grill' 'boulevard' 'bouterin'
#  "bradshaw's restaurant" 'brasserie le coze' "brent's deli"
#  'brighton coffee shop' 'bristol farms market cafe' 'broadway deli'
#  'broiler' 'brookhaven cafe' 'brothers bar-b-q' 'bruno' "bruno's"
#  'bryant park grill  roof restaurant and bp cafe' 'buca giovanni'
#  'buccaneer bay club' 'buckhead diner' "bugsy's diner"
#  "buzio's in the rio" 'c3' "ca'brea" "ca'del sol"
#  'cafe  ritz-carlton  buckhead' "cafe '50s" 'cafe adriano' 'cafe bianco'
#  'cafe bizou' 'cafe blanc' 'cafe botanica' 'cafe centro' 'cafe claude'
#  'cafe con leche' 'cafe des artistes' 'cafe fes' 'cafe flore'
#  'cafe la fortuna' 'cafe lalo' 'cafe luxembourg' 'cafe marimba'
#  'cafe michelle' 'cafe pierre' 'cafe pinot' 'cafe renaissance' 'cafe roma'
#  'cafe sunflower' 'caffe bondi ristorante' 'caffe dante'
#  "caffe dell'artista" 'caffe greco' 'caffe lure' 'caffe reggio'
#  'caffe roma' 'caffe vivaldi' 'california culinary academy'
#  'california pizza kitchen' "camille's" 'campanile' 'campo santo'
#  'campton place' 'canoe' "canter's" "capozzoli's" "capp's corner"
#  'capsouto freres' "captain's table" "carey's" "carey's corner"
#  "carmine's" 'carnegie deli' 'carnival world' 'carta' 'casa la femme'
#  "cassell's" 'cassis' 'cava' 'cendrillon asian grill & marimba bar'
#  'center stage plaza hotel' 'cha cha cha' "cha cha cha's" 'chan dara'
#  'chanterelle' 'chevys' 'chez jacqueline' 'chez melange' 'chez michel'
#  'chiam' "chin's" 'china grill' 'chinois on main' 'chops' 'chopstix'
#  'ciboulette' 'ciboulette restaurant' 'circus circus' 'cite' 'citrus'
#  'city grill' 'clearwater cafe' 'coco loco' 'coco pazzo'
#  'colonnade restaurant' 'columbus bakery' 'corner bistro' 'corrado cafe'
#  'coyote cafe' 'coyote cafe (las vegas)' 'ct' 'cucina della fontana'
#  'cucina di pesce' 'cupcake cafe' 'cypress club' 'da nico' 'daniel'
#  "dante's down the hatch" "dante's down the hatch  buckhead" 'darbar'
#  'dawat' "deacon burton's soulfood restaurant" 'dean & deluca'
#  'delectables' 'des alpes' 'diaghilev' 'dining room'
#  'dining room  ritz-carlton  buckhead' 'diva' 'dive!' 'dix et sept'
#  'docks' "doidge's" "don antonio's" "dottie's true blue cafe" 'drago'
#  "drai's" 'duane park cafe' "duke's" 'dusit thai' 'dynasty room' 'eats'
#  'ebisu' 'eclipse' "ed debevic's" 'edison cafe' "ej's luncheonette"
#  'el cholo' "el teddy's" 'elias corner' 'emerald garden restaurant'
#  "emeril's new orleans fish house" "emily's" 'empire korea'
#  'empress court' "eric's chinese restaurant" "ernie's" 'evergreen cafe'
#  'f. ille ponte ristorante' 'falafel king' "fat matt's rib shack" 'faz'
#  'feast' 'feast from the east' 'felidia' 'felix' 'fenix'
#  'fenix at the argyle' 'ferrier' 'fifty seven fifty seven'
#  'film center cafe' 'fiore rotisserie & grille' "fiorello's roman cafe"
#  'firehouse' 'first' 'fishin eddie' 'fleur de jour' 'fleur de lys'
#  'flowers' 'flying biscuit  the' 'fog city diner' 'follonico'
#  'four seasons' 'four seasons grill room' 'fraunces tavern'
#  'french quarter food shop' 'french roast' 'french roast cafe' 'frico bar'
#  'frijoleros' 'fringale' 'fujiyama mama' "gabriela's" "gallagher's"
#  'garden court' "gaylord's" 'georgia grille' "gianni's" "gilliland's"
#  'girafe' "gladstone's" 'global' 'golden nugget hotel' 'golden steer'
#  'golden unicorn' 'good enough to eat' 'gotham bar & grill'
#  'gramercy tavern' 'grand cafe hotel monaco' 'grand ticino' 'granita'
#  "gray's papaya" 'greens' "greenwood's" 'grill  the' 'grill on the alley'
#  'gumbo pot  the' 'halcyon' "hamburger mary's" 'harbor village'
#  'hard rock cafe' "harold's barbecue" "harris'" "harry denton's"
#  "harry's bar & american grill" 'havana sandwich shop' 'hawthorne lane'
#  'hayes street grill' 'hedgerose heights inn' 'hedgerose heights inn  the'
#  'heera of india' 'helmand' 'hi-life restaurant and lounge'
#  'hollywood hills coffee shop' 'holt bros. bar-b-q' 'home'
#  'hong kong flower lounge' 'hong kong villa' 'horseradish grill'
#  'hotel bel-air' 'house of chan' "hsu's gourmet" 'hudson river club'
#  "hugo's cellar" 'hyde street bistro' 'i trulli' 'il cortile'
#  'il fornaio cucina italiana' "il fornaio levi's plaza" 'il mulino'
#  'il nido' 'imperial fez' 'inca grill' 'indian delights'
#  'indigo coastal grill' 'indo cafe' 'indochine' 'internet cafe' 'ipanema'
#  'island spice' "izzy's steak & chop house" "jack sprat's grill" "jack's"
#  'jackson diner' "jackson's farm" "jan's family restaurant" 'java jive'
#  'jean lafitte' 'jewel of india' "jimmy sung's" "jimmy's" 'jiraffe'
#  'jo jo' "jody maroni's sausage kingdom" 'joe allen' "joe's"
#  "joe's shanghai" "john o'groats" "john's pizzeria" "johnnie's pastrami"
#  "johnny reb's southern smokehouse" 'johnny rockets (at)'
#  'johnny rockets (la)' 'joss' 'judson grill' 'kabuto sushi'
#  "kalo's coffee house" 'kamogawa' "katia's" 'katsu' 'kelley & ping'
#  "kelly's on trinity" 'khan toke thai house' 'kiev' 'killer shrimp'
#  'kokomo cafe' 'koo koo roo' "kuleto's" 'kuruma zushi'
#  'kyo-ya. sheraton palace hotel' "l'absinthe" "l'auberge"
#  "l'auberge du midi" "l'orangerie" "l'osteria del forno" "l'udo"
#  'la cachette' 'la caravelle' 'la caridad' 'la cote basque' 'la cumbre'
#  'la folie' 'la fonda latina' 'la grenouille' 'la grotta'
#  'la grotta at ravinia dunwoody rd.' 'la mediterranee' 'la reserve'
#  'la salsa (la)' 'la serenata de garibaldi' 'la taqueria' "langer's"
#  'lanza restaurant' 'lattanzi ristorante' 'layla' 'le bernardin'
#  'le central' 'le chantilly' 'le chardonnay' 'le chardonnay (los angeles)'
#  'le colonial' 'le dome' 'le gamin' 'le jardin' 'le madri' 'le marais'
#  'le montrachet' 'le montrachet bistro' 'le perigord' 'le select'
#  'le soleil' 'lemongrass grill' 'les celebrites' 'les halles' 'lespinasse'
#  'lespinasse (new york city)' 'lettuce souprise you (at)'
#  "lillie langtry's" 'lincoln tavern' 'little szechuan' 'local nochol'
#  'locanda veneta' 'lola' "lombardi's" "louise's trattoria"
#  'lowcountry barbecue' 'lucky strike' 'lulu' 'lulu restaurant-bis-cafe'
#  'luna si' 'lutece' 'macarthur park' 'mad fish' "madame ching's"
#  'main course  the' 'main street' 'majestic' 'mambo restaurante cubano'
#  'mandarin court' 'mangia e bevi' 'manhattan cafe' 'manhattan ocean club'
#  "mani's bakery & espresso bar" 'manila garden' 'manora' 'march'
#  "margarita's mexican cantina" 'marichu'
#  "mario's bohemian cigar store cafe" 'marnee thai' "marnie's noodle shop"
#  'marquet patisserie' "martha's" "mary mac's tea room" "mary's diner"
#  "masa's" 'match' 'matsuhisa' "matthew's" 'mavalli palace'
#  "maxwell's cafe" 'mayflower cuisinier' 'maykadeh' "mccormick & kuleto's"
#  "mckinnon's louisiane" "mel's drive-in" 'menchanko-tei' 'mesa grill'
#  'mi cocina' 'mi spia dunwoody rd.' "michael's (las vegas)"
#  "michael's (los angeles)" 'mifune'
#  'mifune japan center  kintetsu building' 'mikado'
#  'milan cafe and coffee bar' 'millennium' 'mishima' 'mitali east-west'
#  'mo better meatty meat' "mo's burgers" 'mon kee seafood restaurant'
#  'monkey bar' 'monsoon (ny)' 'monte carlo' 'montien' 'montrachet'
#  'moongate' "moose's" "morton's" "morton's of chicago (atlanta)"
#  "morton's of chicago (las vegas)" 'motown cafe' 'moustache'
#  'mulberry st.' 'my thai' "nate 'n' al's" 'nava'
#  'new york kom tang soot bul house' 'new york noodletown' 'newsbar'
#  "nickiemoto's: a sushi bar" "nicky blair's" 'nicola' "nikolai's roof"
#  'nobu' 'north india' 'nuevo laredo cantina' 'ocean avenue'
#  'ocean park cafe' 'ocean star' 'oceana' 'odeon' 'one if by land  tibs'
#  'one market' 'original pancake house (at)' 'original pantry bakery'
#  'oritalia' 'orleans' 'orso' 'osteria al droge' 'otabe' 'oyster bar'
#  'pacific dining car' 'pacific pan pacific hotel' 'pacifica'
#  'palace court' 'palio' "palio d'asti" 'palisades' 'palm'
#  'palm  the (atlanta)' 'palm  the (los angeles)' 'palm too' 'pamir'
#  'pamplemousse' 'pane e vino' "pano's & paul's" "pano's and paul's"
#  'parioli romanissimo' 'park avenue cafe'
#  'park avenue cafe (new york city)' 'parkway grill' 'pastis' 'patina'
#  'patria' "patsy's pizza" "paty's" 'peacock alley' 'pen & pencil'
#  'penang soho' "perry's" 'persepolis' 'peter luger steak house'
#  'petrossian' 'philippe the original' "philippe's the original"
#  'phnom penh cambodian restaurant' 'pho hoa' 'picholine'
#  "piero's restaurant" "pink's famous chili dogs" 'pinot bistro'
#  'pinot hollywood' 'pisces' 'planet hollywood' 'pleasant peasant'
#  'plumpjack cafe' 'pomaire' 'popover cafe' 'poquito mas' 'post house'
#  'posto' 'postrio' 'prego' 'pricci' 'r&g lounge' 'r-23'
#  "r.j.'s uptown kitchen & wine bar" "rae's" 'rain' 'rainbow restaurant'
#  'rainbow room' "ralph's diner" 'red tulip' 'remi' 'republic'
#  'restaurant  ritz-carlton  atlanta' 'restaurant horikawa'
#  'restaurant katsu' 'rex il ristorante' 'rib ranch'
#  'ritz-carlton cafe (atlanta)' 'ritz-carlton cafe (buckhead)'
#  'ritz-carlton dining room (buckhead)'
#  'ritz-carlton dining room (san francisco)' 'ritz-carlton restaurant'
#  'ritz-carlton restaurant and dining room' 'river cafe' 'riviera'
#  "rj's the rib joint" 'roettelle a. g' 'roosevelt tamale parlor'
#  'rosa mexicano' "roscoe's house of chicken 'n' waffles" 'rose of india'
#  'rose pistola' 'rubicon' "rubin's red hots" "ruby's (la)" 'rumpus'
#  "russell's burgers" "ruth's chris"
#  "ruth's chris steak house (los angeles)" 's.p.q.r' 'sa tsu ki'
#  "sal anthony's" "sally's cafe & bakery" "sam's noodle shop"
#  "sammy's roumanian steak house" 'san domenico' 'san francisco bbq'
#  'san pietro' 'sanppo' 'sant ambroeus' "sarabeth's" "sarabeth's kitchen"
#  'sato sushi and thai' "scala's bistro" 'schatzi on main' 'sea grill'
#  'second avenue deli' 'second street grill' 'second street grille'
#  'serendipity' 'seryna' 'seventh regiment mess and bar' 'sfuzzi' 'shaan'
#  'shiro' 'shun lee palace' 'shun lee west' 'sign of the dove'
#  'silver skillet  the' 'slanted door' 'smith & wollensky' 'sofi'
#  'sofia fabulous pizza' 'soto' 'south city kitchen' 'south of france'
#  'south park cafe' 'spago' 'spago (las vegas)' 'spago (los angeles)'
#  'sparks steak house' 'splendido embarcadero'
#  'spring street natural restaurant & bar' 'stage deli' 'stars'
#  'stars cafe' 'steak house' 'steak house  the' 'steakhouse  the'
#  "stefano's" 'sterling brunch' 'stick to your ribs' 'stingray'
#  "stoyanof's cafe" 'straits cafe' "stringer's fish camp and oyster bar"
#  'sundown cafe' 'suppenkuche' 'sushi nozawa' 'sushisay'
#  'swan oyster depot' 'sweet lady jane' "sweet'n'tart cafe" 'swingers'
#  "sylvia's" 'szechuan hunan cottage' 'szechuan kitchen' 't salon'
#  'tadich grill' 'taiko' 'tang pavillion' 'tapika' 'taste of new orleans'
#  'tavern on the green' 'tavola calda' "teresa's" 'terrace'
#  'thai house cafe' 'thailand restaurant' 'the bacchanal' 'the coffee pot'
#  'the heights' 'the mandarin' 'the palm' 'the savannah club'
#  "thelma's kitchen" 'thep phanom' 'thepin' 'ti couz' 'tillerman'
#  'tillerman  the' "tommy tang's" "tommy's" 'tomtom' 'ton kiang'
#  'tortillas' 'toulouse' 'tra di noi' "trader vic's" "trattoria dell'arte"
#  'tre visi' 'triangolo' 'tribeca grill' 'trio cafe' 'trois jean'
#  'tse yang' 'tu lan' 'turkish kitchen' 'two two two'
#  "uncle bill's pancake house" "uncle nick's" 'union square cafe'
#  'valentino' "van gogh's restaurant & bar" 'veggieland' 'venetian'
#  'veni vidi vici' "veniero's pasticceria" 'verbena' 'vertigo' 'veselka'
#  'vicolo pizzeria' "victor's cafe" 'vida' "vince & eddie's" "virgil's"
#  "virgil's real bbq" "viva mercado's" 'vivande porta via'
#  'vivande ristorante' 'vong' 'wa-ha-ka oaxaca mexican grill' 'water club'
#  'water grill' 'west' 'west beach cafe' 'westside cottage'
#  'white house restaurant' 'windows on the world' "wollensky's grill"
#  'world wrapps' 'wu kong' 'xunta' 'yama' 'yank sing' 'yaya cuisine'
#  "yolie's" 'yoyo tsumami bistro' "yujean kang's"
#  "yujean kang's gourmet chinese cuisine" 'zab-e-lee' 'zankou chicken'
#  'zarela' 'zarzuela' 'zen palate' 'zoe' 'zuni cafe & grill']
# ### city
# ['atlanta' 'bel air' 'beverly hills' 'brentwood' 'brooklyn' 'burbank'
#  'century city' 'chinatown' 'college park' 'culver city' 'decatur'
#  'duluth' 'encino' 'glendale' 'hollywood' 'la' 'las vegas' 'long beach'
#  'los angeles' 'los feliz' 'malibu' 'manhattan beach' 'mar vista'
#  'marietta' 'marina del rey' 'monterey park' 'new york' 'new york city'
#  'northridge' 'pacific palisades' 'pasadena' 'queens' 'rancho park'
#  'redondo beach' 'roswell' 'san francisco' 'santa monica' 'seal beach'
#  'sherman oaks' 'smyrna' 'st. boyle hts.' 'st. hermosa beach'
#  'studio city' 'toluca lake' 'venice' 'w. hollywood' 'west la'
#  'westlake village' 'westwood']

# %%
import textdistance as td
import numpy as np

unames = data.name.unique()
unames.sort()
unames

list_d = [(p1, p2, td.hamming(p1, p2)) for p1 in unames for p2 in unames]
list(list_d)
# Out:
# [('103 west', '103 west', 0),
#  ('103 west', '20 mott', 7),
#  ('103 west', '21 club', 8),
#  ('103 west', '2223', 8),
#  ('103 west', '9 jones street', 12),
#  ('103 west', 'abbey', 8),
#  ('103 west', 'abruzzi', 8),
#  ('103 west', 'acquarello', 10),
#  ('103 west', "adriano's ristorante", 20),
#  ('103 west', 'adrienne', 8),
#  ('103 west', 'afghan kebab house', 18),
#  ('103 west', 'agrotikon', 9),
#  ('103 west', 'aja', 8),
#  ('103 west', 'alain rondelli', 14),
#  ('103 west', 'alamo', 8),
#  ('103 west', "aleck's barbecue heaven", 22),
#  ('103 west', "alley's end", 10),
#  ('103 west', "alon's at the terrace", 21),
#  ('103 west', 'ambassador grill', 16),
#  ('103 west', 'american place', 14),
#  ('103 west', 'anche vivolo', 12),
#  ('103 west', "andre's french restaurant", 24),
#  ('103 west', "annie's thai castle", 18),
#  ('103 west', 'anthonys', 8),
#  ('103 west', "antonio's", 9),
#  ('103 west', 'apple pan  the', 14),
#  ('103 west', 'aqua', 8),
#  ('103 west', 'aquavit', 8),
#  ('103 west', 'arcadia', 8),
#  ('103 west', 'arizona', 8),
#  ('103 west', "arnie morton's of chicago", 25),
#  ('103 west', "art's deli", 10),
#  ('103 west', "art's delicatessen", 18),
#  ('103 west', "arturo's", 8),
#  ('103 west', 'asahi ramen', 11),
#  ('103 west', 'atlanta fish market', 19),
#  ('103 west', 'au mandarin', 11),
#  ('103 west', 'aureole', 8),
#  ('103 west', 'bacchanalia', 11),
#  ('103 west', 'baja fresh', 10),
#  ('103 west', "baker's cajun cafe", 17),
#  ('103 west', "bally's big kitchen", 18),
#  ('103 west', 'bamboo garden', 13),
#  ('103 west', 'bar anise', 8),
#  ('103 west', 'barbecue kitchen', 16),
#  ('103 west', 'barbetta', 8),
#  ('103 west', "bardelli's", 10),
#  ('103 west', 'barney greengrass', 17),
#  ('103 west', "battista's hole in the wall", 27),
#  ('103 west', 'beaurivage', 10),
#  ('103 west', "beesley's of buckhead", 20),
#  ('103 west', 'bel-air hotel', 13),
#  ('103 west', 'belvedere  the', 14),
#  ('103 west', "ben benson's", 10),
#  ('103 west', "benita's frites", 15),
#  ('103 west', "benny's burritos", 15),
#  ('103 west', "bernard's", 9),
#  ('103 west', "bertolini's", 11),
#  ('103 west', 'betelnut', 7),
#  ('103 west', 'big cup', 7),
#  ('103 west', "bill's place", 12),
#  ('103 west', "billy's", 7),
#  ('103 west', "binion's coffee shop", 20),
#  ('103 west', 'bistango', 8),
#  ('103 west', 'bistro', 8),
#  ('103 west', 'bistro  the', 11),
#  ('103 west', 'bistro 45', 9),
#  ('103 west', 'bistro garden', 13),
#  ('103 west', 'bistro roti', 11),
#  ('103 west', 'bix', 8),
#  ('103 west', 'bizou', 8),
#  ('103 west', "bobby & june's kountry kitchen", 30),
#  ('103 west', 'boca chica', 10),
#  ('103 west', 'bolo', 8),
#  ('103 west', "bone's", 8),
#  ('103 west', "bone's restaurant", 17),
#  ('103 west', 'boonthai', 8),
#  ('103 west', 'border grill', 12),
#  ('103 west', 'boulevard', 9),
#  ('103 west', 'bouterin', 8),
#  ('103 west', "bradshaw's restaurant", 21),
#  ('103 west', 'brasserie le coze', 16),
#  ('103 west', "brent's deli", 11),
#  ('103 west', 'brighton coffee shop', 20),
#  ('103 west', 'bristol farms market cafe', 25),
#  ('103 west', 'broadway deli', 13),
#  ('103 west', 'broiler', 7),
#  ('103 west', 'brookhaven cafe', 15),
#  ('103 west', 'brothers bar-b-q', 15),
#  ('103 west', 'bruno', 8),
#  ('103 west', "bruno's", 7),
#  ('103 west', 'bryant park grill  roof restaurant and bp cafe', 46),
#  ('103 west', 'buca giovanni', 13),
#  ('103 west', 'buccaneer bay club', 18),
#  ('103 west', 'buckhead diner', 13),
#  ('103 west', "bugsy's diner", 12),
#  ('103 west', "buzio's in the rio", 17),
#  ('103 west', 'c3', 8),
#  ('103 west', "ca'brea", 7),
#  ('103 west', "ca'del sol", 10),
#  ('103 west', 'cafe  ritz-carlton  buckhead', 28),
#  ('103 west', "cafe '50s", 9),
#  ('103 west', 'cafe adriano', 12),
#  ('103 west', 'cafe bianco', 11),
#  ('103 west', 'cafe bizou', 10),
#  ('103 west', 'cafe blanc', 10),
#  ('103 west', 'cafe botanica', 12),
#  ('103 west', 'cafe centro', 11),
#  ('103 west', 'cafe claude', 11),
#  ('103 west', 'cafe con leche', 14),
#  ('103 west', 'cafe des artistes', 17),
#  ('103 west', 'cafe fes', 8),
#  ('103 west', 'cafe flore', 10),
#  ('103 west', 'cafe la fortuna', 15),
#  ('103 west', 'cafe lalo', 9),
#  ('103 west', 'cafe luxembourg', 15),
#  ('103 west', 'cafe marimba', 12),
#  ('103 west', 'cafe michelle', 13),
#  ('103 west', 'cafe pierre', 11),
#  ('103 west', 'cafe pinot', 10),
#  ('103 west', 'cafe renaissance', 16),
#  ('103 west', 'cafe roma', 9),
#  ('103 west', 'cafe sunflower', 14),
#  ('103 west', 'caffe bondi ristorante', 22),
#  ('103 west', 'caffe dante', 11),
#  ('103 west', "caffe dell'artista", 18),
#  ('103 west', 'caffe greco', 11),
#  ('103 west', 'caffe lure', 10),
#  ('103 west', 'caffe reggio', 12),
#  ('103 west', 'caffe roma', 10),
#  ('103 west', 'caffe vivaldi', 13),
#  ('103 west', 'california culinary academy', 27),
#  ('103 west', 'california pizza kitchen', 24),
#  ('103 west', "camille's", 9),
#  ('103 west', 'campanile', 9),
#  ('103 west', 'campo santo', 10),
#  ('103 west', 'campton place', 13),
#  ('103 west', 'canoe', 8),
#  ('103 west', "canter's", 8),
#  ('103 west', "capozzoli's", 11),
#  ('103 west', "capp's corner", 13),
#  ('103 west', 'capsouto freres', 15),
#  ('103 west', "captain's table", 15),
#  ('103 west', "carey's", 7),
#  ('103 west', "carey's corner", 13),
#  ('103 west', "carmine's", 9),
#  ('103 west', 'carnegie deli', 13),
#  ('103 west', 'carnival world', 14),
#  ('103 west', 'carta', 8),
#  ('103 west', 'casa la femme', 13),
#  ('103 west', "cassell's", 9),
#  ('103 west', 'cassis', 8),
#  ('103 west', 'cava', 8),
#  ('103 west', 'cendrillon asian grill & marimba bar', 36),
#  ('103 west', 'center stage plaza hotel', 24),
#  ('103 west', 'cha cha cha', 10),
#  ('103 west', "cha cha cha's", 12),
#  ('103 west', 'chan dara', 9),
#  ('103 west', 'chanterelle', 10),
#  ('103 west', 'chevys', 8),
#  ('103 west', 'chez jacqueline', 15),
#  ('103 west', 'chez melange', 12),
#  ('103 west', 'chez michel', 11),
#  ('103 west', 'chiam', 8),
#  ('103 west', "chin's", 8),
#  ('103 west', 'china grill', 11),
#  ('103 west', 'chinois on main', 14),
#  ('103 west', 'chops', 8),
#  ('103 west', 'chopstix', 8),
#  ('103 west', 'ciboulette', 9),
#  ('103 west', 'ciboulette restaurant', 20),
#  ('103 west', 'circus circus', 13),
#  ('103 west', 'cite', 8),
#  ('103 west', 'citrus', 8),
#  ('103 west', 'city grill', 10),
#  ('103 west', 'clearwater cafe', 14),
#  ('103 west', 'coco loco', 9),
#  ('103 west', 'coco pazzo', 10),
#  ('103 west', 'colonnade restaurant', 20),
#  ('103 west', 'columbus bakery', 15),
#  ('103 west', 'corner bistro', 13),
#  ('103 west', 'corrado cafe', 12),
#  ('103 west', 'coyote cafe', 10),
#  ('103 west', 'coyote cafe (las vegas)', 22),
#  ('103 west', 'ct', 8),
#  ('103 west', 'cucina della fontana', 20),
#  ('103 west', 'cucina di pesce', 15),
#  ('103 west', 'cupcake cafe', 12),
#  ('103 west', 'cypress club', 11),
#  ('103 west', 'da nico', 8),
#  ('103 west', 'daniel', 8),
#  ('103 west', "dante's down the hatch", 21),
#  ('103 west', "dante's down the hatch  buckhead", 31),
#  ('103 west', 'darbar', 8),
#  ('103 west', 'dawat', 8),
#  ('103 west', "deacon burton's soulfood restaurant", 35),
#  ('103 west', 'dean & deluca', 13),
#  ('103 west', 'delectables', 11),
#  ('103 west', 'des alpes', 8),
#  ('103 west', 'diaghilev', 9),
#  ('103 west', 'dining room', 11),
#  ('103 west', 'dining room  ritz-carlton  buckhead', 35),
#  ('103 west', 'diva', 8),
#  ('103 west', 'dive!', 8),
#  ('103 west', 'dix et sept', 10),
#  ('103 west', 'docks', 8),
#  ('103 west', "doidge's", 7),
#  ('103 west', "don antonio's", 12),
#  ('103 west', "dottie's true blue cafe", 22),
#  ('103 west', 'drago', 8),
#  ('103 west', "drai's", 8),
#  ('103 west', 'duane park cafe', 15),
#  ('103 west', "duke's", 8),
#  ('103 west', 'dusit thai', 10),
#  ('103 west', 'dynasty room', 12),
#  ('103 west', 'eats', 8),
#  ('103 west', 'ebisu', 8),
#  ('103 west', 'eclipse', 8),
#  ('103 west', "ed debevic's", 12),
#  ('103 west', 'edison cafe', 11),
#  ('103 west', "ej's luncheonette", 17),
#  ('103 west', 'el cholo', 8),
#  ('103 west', "el teddy's", 10),
#  ('103 west', 'elias corner', 12),
#  ('103 west', 'emerald garden restaurant', 25),
#  ('103 west', "emeril's new orleans fish house", 31),
#  ('103 west', "emily's", 7),
#  ('103 west', 'empire korea', 11),
#  ('103 west', 'empress court', 12),
#  ('103 west', "eric's chinese restaurant", 25),
#  ('103 west', "ernie's", 7),
#  ('103 west', 'evergreen cafe', 14),
#  ('103 west', 'f. ille ponte ristorante', 24),
#  ('103 west', 'falafel king', 11),
#  ('103 west', "fat matt's rib shack", 18),
#  ('103 west', 'faz', 8),
#  ('103 west', 'feast', 8),
#  ('103 west', 'feast from the east', 19),
#  ('103 west', 'felidia', 8),
#  ('103 west', 'felix', 8),
#  ('103 west', 'fenix', 8),
#  ('103 west', 'fenix at the argyle', 18),
#  ('103 west', 'ferrier', 7),
#  ('103 west', 'fifty seven fifty seven', 22),
#  ('103 west', 'film center cafe', 16),
#  ('103 west', 'fiore rotisserie & grille', 25),
#  ('103 west', "fiorello's roman cafe", 21),
#  ('103 west', 'firehouse', 9),
#  ('103 west', 'first', 8),
#  ('103 west', 'fishin eddie', 12),
#  ('103 west', 'fleur de jour', 13),
#  ('103 west', 'fleur de lys', 12),
#  ('103 west', 'flowers', 7),
#  ('103 west', 'flying biscuit  the', 19),
#  ('103 west', 'fog city diner', 13),
#  ('103 west', 'follonico', 9),
#  ('103 west', 'four seasons', 12),
#  ('103 west', 'four seasons grill room', 23),
#  ('103 west', 'fraunces tavern', 15),
#  ('103 west', 'french quarter food shop', 24),
#  ('103 west', 'french roast', 12),
#  ('103 west', 'french roast cafe', 17),
#  ('103 west', 'frico bar', 9),
#  ('103 west', 'frijoleros', 10),
#  ('103 west', 'fringale', 8),
#  ('103 west', 'fujiyama mama', 13),
#  ('103 west', "gabriela's", 9),
#  ('103 west', "gallagher's", 11),
#  ('103 west', 'garden court', 12),
#  ('103 west', "gaylord's", 9),
#  ('103 west', 'georgia grille', 14),
#  ('103 west', "gianni's", 8),
#  ('103 west', "gilliland's", 11),
#  ('103 west', 'girafe', 7),
#  ('103 west', "gladstone's", 11),
#  ('103 west', 'global', 8),
#  ('103 west', 'golden nugget hotel', 19),
#  ('103 west', 'golden steer', 12),
#  ('103 west', 'golden unicorn', 14),
#  ('103 west', 'good enough to eat', 17),
#  ('103 west', 'gotham bar & grill', 18),
#  ('103 west', 'gramercy tavern', 15),
#  ('103 west', 'grand cafe hotel monaco', 23),
#  ('103 west', 'grand ticino', 12),
#  ('103 west', 'granita', 8),
#  ('103 west', "gray's papaya", 13),
#  ('103 west', 'greens', 8),
#  ('103 west', "greenwood's", 11),
#  ('103 west', 'grill  the', 9),
#  ('103 west', 'grill on the alley', 18),
#  ('103 west', 'gumbo pot  the', 14),
#  ('103 west', 'halcyon', 8),
#  ('103 west', "hamburger mary's", 16),
#  ('103 west', 'harbor village', 14),
#  ('103 west', 'hard rock cafe', 14),
#  ('103 west', "harold's barbecue", 17),
#  ('103 west', "harris'", 8),
#  ('103 west', "harry denton's", 14),
#  ('103 west', "harry's bar & american grill", 27),
#  ('103 west', 'havana sandwich shop', 20),
#  ('103 west', 'hawthorne lane', 14),
#  ('103 west', 'hayes street grill', 16),
#  ('103 west', 'hedgerose heights inn', 21),
#  ('103 west', 'hedgerose heights inn  the', 26),
#  ('103 west', 'heera of india', 14),
#  ('103 west', 'helmand', 8),
#  ('103 west', 'hi-life restaurant and lounge', 29),
#  ('103 west', 'hollywood hills coffee shop', 27),
#  ('103 west', 'holt bros. bar-b-q', 18),
#  ('103 west', 'home', 8),
#  ('103 west', 'hong kong flower lounge', 23),
#  ('103 west', 'hong kong villa', 15),
#  ('103 west', 'horseradish grill', 17),
#  ('103 west', 'hotel bel-air', 13),
#  ('103 west', 'house of chan', 13),
#  ('103 west', "hsu's gourmet", 13),
#  ('103 west', 'hudson river club', 17),
#  ('103 west', "hugo's cellar", 13),
#  ('103 west', 'hyde street bistro', 18),
#  ('103 west', 'i trulli', 8),
#  ('103 west', 'il cortile', 10),
#  ('103 west', 'il fornaio cucina italiana', 26),
#  ('103 west', "il fornaio levi's plaza", 23),
#  ('103 west', 'il mulino', 9),
#  ('103 west', 'il nido', 8),
#  ('103 west', 'imperial fez', 12),
#  ('103 west', 'inca grill', 10),
#  ('103 west', 'indian delights', 15),
#  ('103 west', 'indigo coastal grill', 20),
#  ('103 west', 'indo cafe', 9),
#  ('103 west', 'indochine', 9),
#  ('103 west', 'internet cafe', 12),
#  ('103 west', 'ipanema', 8),
#  ('103 west', 'island spice', 12),
#  ('103 west', "izzy's steak & chop house", 25),
#  ('103 west', "jack sprat's grill", 18),
#  ('103 west', "jack's", 8),
#  ('103 west', 'jackson diner', 13),
#  ('103 west', "jackson's farm", 14),
#  ('103 west', "jan's family restaurant", 23),
#  ('103 west', 'java jive', 9),
#  ('103 west', 'jean lafitte', 12),
#  ('103 west', 'jewel of india', 14),
#  ('103 west', "jimmy sung's", 11),
#  ('103 west', "jimmy's", 7),
#  ('103 west', 'jiraffe', 8),
#  ('103 west', 'jo jo', 8),
#  ('103 west', "jody maroni's sausage kingdom", 29),
#  ('103 west', 'joe allen', 8),
#  ('103 west', "joe's", 8),
#  ('103 west', "joe's shanghai", 13),
#  ('103 west', "john o'groats", 13),
#  ('103 west', "john's pizzeria", 15),
#  ('103 west', "johnnie's pastrami", 18),
#  ('103 west', "johnny reb's southern smokehouse", 32),
#  ('103 west', 'johnny rockets (at)', 19),
#  ('103 west', 'johnny rockets (la)', 19),
#  ('103 west', 'joss', 8),
#  ('103 west', 'judson grill', 12),
#  ('103 west', 'kabuto sushi', 12),
#  ('103 west', "kalo's coffee house", 19),
#  ('103 west', 'kamogawa', 8),
#  ('103 west', "katia's", 7),
#  ('103 west', 'katsu', 8),
#  ('103 west', 'kelley & ping', 13),
#  ('103 west', "kelly's on trinity", 17),
#  ('103 west', 'khan toke thai house', 20),
#  ('103 west', 'kiev', 8),
#  ('103 west', 'killer shrimp', 13),
#  ('103 west', 'kokomo cafe', 11),
#  ('103 west', 'koo koo roo', 10),
#  ('103 west', "kuleto's", 8),
#  ('103 west', 'kuruma zushi', 12),
#  ('103 west', 'kyo-ya. sheraton palace hotel', 29),
#  ('103 west', "l'absinthe", 9),
#  ('103 west', "l'auberge", 8),
#  ('103 west', "l'auberge du midi", 16),
#  ('103 west', "l'orangerie", 11),
#  ('103 west', "l'osteria del forno", 18),
#  ('103 west', "l'udo", 8),
#  ('103 west', 'la cachette', 11),
#  ('103 west', 'la caravelle', 12),
#  ('103 west', 'la caridad', 10),
#  ('103 west', 'la cote basque', 14),
#  ('103 west', 'la cumbre', 9),
#  ('103 west', 'la folie', 8),
#  ('103 west', 'la fonda latina', 15),
#  ('103 west', 'la grenouille', 12),
#  ('103 west', 'la grotta', 8),
#  ('103 west', 'la grotta at ravinia dunwoody rd.', 32),
#  ('103 west', 'la mediterranee', 14),
#  ('103 west', 'la reserve', 10),
#  ('103 west', 'la salsa (la)', 12),
#  ('103 west', 'la serenata de garibaldi', 24),
#  ('103 west', 'la taqueria', 11),
#  ('103 west', "langer's", 8),
#  ('103 west', 'lanza restaurant', 16),
#  ('103 west', 'lattanzi ristorante', 19),
#  ('103 west', 'layla', 8),
#  ('103 west', 'le bernardin', 12),
#  ('103 west', 'le central', 10),
#  ('103 west', 'le chantilly', 11),
#  ('103 west', 'le chardonnay', 13),
#  ('103 west', 'le chardonnay (los angeles)', 27),
#  ('103 west', 'le colonial', 11),
#  ('103 west', 'le dome', 8),
#  ('103 west', 'le gamin', 8),
#  ('103 west', 'le jardin', 9),
#  ('103 west', 'le madri', 8),
#  ('103 west', 'le marais', 9),
#  ('103 west', 'le montrachet', 13),
#  ('103 west', 'le montrachet bistro', 20),
#  ('103 west', 'le perigord', 11),
#  ('103 west', 'le select', 9),
#  ('103 west', 'le soleil', 9),
#  ('103 west', 'lemongrass grill', 16),
#  ('103 west', 'les celebrites', 12),
#  ('103 west', 'les halles', 9),
#  ('103 west', 'lespinasse', 10),
#  ('103 west', 'lespinasse (new york city)', 26),
#  ('103 west', 'lettuce souprise you (at)', 25),
#  ('103 west', "lillie langtry's", 15),
#  ('103 west', 'lincoln tavern', 14),
#  ('103 west', 'little szechuan', 14),
#  ('103 west', 'local nochol', 12),
#  ('103 west', 'locanda veneta', 14),
#  ('103 west', 'lola', 8),
#  ('103 west', "lombardi's", 10),
#  ('103 west', "louise's trattoria", 17),
#  ('103 west', 'lowcountry barbecue', 18),
#  ('103 west', 'lucky strike', 10),
#  ('103 west', 'lulu', 8),
#  ('103 west', 'lulu restaurant-bis-cafe', 24),
#  ('103 west', 'luna si', 8),
#  ('103 west', 'lutece', 7),
#  ('103 west', 'macarthur park', 14),
#  ('103 west', 'mad fish', 6),
#  ('103 west', "madame ching's", 13),
#  ('103 west', 'main course  the', 16),
#  ('103 west', 'main street', 11),
#  ('103 west', 'majestic', 8),
#  ('103 west', 'mambo restaurante cubano', 24),
#  ('103 west', 'mandarin court', 14),
#  ('103 west', 'mangia e bevi', 13),
#  ('103 west', 'manhattan cafe', 14),
#  ('103 west', 'manhattan ocean club', 20),
#  ('103 west', "mani's bakery & espresso bar", 28),
#  ('103 west', 'manila garden', 13),
#  ('103 west', 'manora', 8),
#  ('103 west', 'march', 8),
#  ('103 west', "margarita's mexican cantina", 26),
#  ('103 west', 'marichu', 8),
#  ('103 west', "mario's bohemian cigar store cafe", 32),
#  ('103 west', 'marnee thai', 9),
#  ('103 west', "marnie's noodle shop", 19),
#  ('103 west', 'marquet patisserie', 17),
#  ('103 west', "martha's", 8),
#  ('103 west', "mary mac's tea room", 19),
#  ('103 west', "mary's diner", 12),
#  ('103 west', "masa's", 8),
#  ('103 west', 'match', 8),
#  ('103 west', 'matsuhisa', 9),
#  ('103 west', "matthew's", 8),
#  ('103 west', 'mavalli palace', 14),
#  ('103 west', "maxwell's cafe", 14),
#  ('103 west', 'mayflower cuisinier', 19),
#  ('103 west', 'maykadeh', 8),
#  ('103 west', "mccormick & kuleto's", 20),
#  ('103 west', "mckinnon's louisiane", 20),
#  ('103 west', "mel's drive-in", 14),
#  ('103 west', 'menchanko-tei', 13),
#  ('103 west', 'mesa grill', 10),
#  ('103 west', 'mi cocina', 9),
#  ('103 west', 'mi spia dunwoody rd.', 20),
#  ('103 west', "michael's (las vegas)", 20),
#  ('103 west', "michael's (los angeles)", 22),
#  ('103 west', 'mifune', 7),
#  ('103 west', 'mifune japan center  kintetsu building', 37),
#  ('103 west', 'mikado', 8),
#  ('103 west', 'milan cafe and coffee bar', 25),
#  ('103 west', 'millennium', 10),
#  ('103 west', 'mishima', 8),
#  ('103 west', 'mitali east-west', 16),
#  ('103 west', 'mo better meatty meat', 21),
#  ('103 west', "mo's burgers", 12),
#  ('103 west', 'mon kee seafood restaurant', 24),
#  ('103 west', 'monkey bar', 10),
#  ('103 west', 'monsoon (ny)', 12),
#  ('103 west', 'monte carlo', 11),
#  ('103 west', 'montien', 7),
#  ('103 west', 'montrachet', 10),
#  ('103 west', 'moongate', 8),
#  ('103 west', "moose's", 7),
#  ('103 west', "morton's", 8),
#  ('103 west', "morton's of chicago (atlanta)", 29),
#  ('103 west', "morton's of chicago (las vegas)", 31),
#  ('103 west', 'motown cafe', 10),
#  ('103 west', 'moustache', 9),
#  ('103 west', 'mulberry st.', 12),
#  ('103 west', 'my thai', 8),
#  ('103 west', "nate 'n' al's", 13),
#  ('103 west', 'nava', 8),
#  ('103 west', 'new york kom tang soot bul house', 31),
#  ('103 west', 'new york noodletown', 18),
#  ('103 west', 'newsbar', 8),
#  ('103 west', "nickiemoto's: a sushi bar", 24),
#  ('103 west', "nicky blair's", 13),
#  ('103 west', 'nicola', 8),
#  ('103 west', "nikolai's roof", 14),
#  ('103 west', 'nobu', 8),
#  ('103 west', 'north india', 11),
#  ('103 west', 'nuevo laredo cantina', 20),
#  ('103 west', 'ocean avenue', 12),
#  ('103 west', 'ocean park cafe', 15),
#  ('103 west', 'ocean star', 8),
#  ('103 west', 'oceana', 8),
#  ('103 west', 'odeon', 8),
#  ('103 west', 'one if by land  tibs', 19),
#  ('103 west', 'one market', 9),
#  ('103 west', 'original pancake house (at)', 27),
#  ('103 west', 'original pantry bakery', 22),
#  ('103 west', 'oritalia', 8),
#  ('103 west', 'orleans', 7),
#  ('103 west', 'orso', 8),
#  ('103 west', 'osteria al droge', 16),
#  ('103 west', 'otabe', 8),
#  ('103 west', 'oyster bar', 10),
#  ('103 west', 'pacific dining car', 18),
#  ('103 west', 'pacific pan pacific hotel', 25),
#  ('103 west', 'pacifica', 8),
#  ('103 west', 'palace court', 11),
#  ('103 west', 'palio', 8),
#  ('103 west', "palio d'asti", 12),
#  ('103 west', 'palisades', 9),
#  ('103 west', 'palm', 8),
#  ('103 west', 'palm  the (atlanta)', 19),
#  ('103 west', 'palm  the (los angeles)', 23),
#  ('103 west', 'palm too', 8),
#  ('103 west', 'pamir', 8),
#  ('103 west', 'pamplemousse', 11),
#  ('103 west', 'pane e vino', 10),
#  ('103 west', "pano's & paul's", 15),
#  ('103 west', "pano's and paul's", 17),
#  ('103 west', 'parioli romanissimo', 19),
#  ('103 west', 'park avenue cafe', 16),
#  ('103 west', 'park avenue cafe (new york city)', 32),
#  ('103 west', 'parkway grill', 12),
#  ('103 west', 'pastis', 8),
#  ('103 west', 'patina', 8),
#  ('103 west', 'patria', 8),
#  ('103 west', "patsy's pizza", 12),
#  ('103 west', "paty's", 8),
#  ('103 west', 'peacock alley', 13),
#  ('103 west', 'pen & pencil', 11),
#  ('103 west', 'penang soho', 11),
#  ('103 west', "perry's", 7),
#  ('103 west', 'persepolis', 10),
#  ('103 west', 'peter luger steak house', 23),
#  ('103 west', 'petrossian', 9),
#  ('103 west', 'philippe the original', 21),
#  ('103 west', "philippe's the original", 23),
#  ('103 west', 'phnom penh cambodian restaurant', 31),
#  ('103 west', 'pho hoa', 7),
#  ('103 west', 'picholine', 9),
#  ('103 west', "piero's restaurant", 17),
#  ('103 west', "pink's famous chili dogs", 24),
#  ('103 west', 'pinot bistro', 12),
#  ('103 west', 'pinot hollywood', 15),
#  ('103 west', 'pisces', 8),
#  ('103 west', 'planet hollywood', 16),
#  ('103 west', 'pleasant peasant', 15),
#  ('103 west', 'plumpjack cafe', 14),
#  ('103 west', 'pomaire', 8),
#  ('103 west', 'popover cafe', 11),
#  ('103 west', 'poquito mas', 11),
#  ('103 west', 'post house', 10),
#  ('103 west', 'posto', 8),
#  ('103 west', 'postrio', 8),
#  ('103 west', 'prego', 8),
#  ('103 west', 'pricci', 8),
#  ('103 west', 'r&g lounge', 9),
#  ('103 west', 'r-23', 8),
#  ('103 west', "r.j.'s uptown kitchen & wine bar", 32),
#  ('103 west', "rae's", 8),
#  ('103 west', 'rain', 8),
#  ('103 west', 'rainbow restaurant', 18),
#  ('103 west', 'rainbow room', 12),
#  ('103 west', "ralph's diner", 12),
#  ('103 west', 'red tulip', 8),
#  ('103 west', 'remi', 8),
#  ('103 west', 'republic', 8),
#  ('103 west', 'restaurant  ritz-carlton  atlanta', 33),
#  ('103 west', 'restaurant horikawa', 19),
#  ('103 west', 'restaurant katsu', 16),
#  ('103 west', 'rex il ristorante', 16),
#  ('103 west', 'rib ranch', 8),
#  ('103 west', 'ritz-carlton cafe (atlanta)', 27),
#  ('103 west', 'ritz-carlton cafe (buckhead)', 28),
#  ('103 west', 'ritz-carlton dining room (buckhead)', 35),
#  ('103 west', 'ritz-carlton dining room (san francisco)', 40),
#  ('103 west', 'ritz-carlton restaurant', 23),
#  ('103 west', 'ritz-carlton restaurant and dining room', 39),
#  ('103 west', 'river cafe', 10),
#  ('103 west', 'riviera', 8),
#  ('103 west', "rj's the rib joint", 18),
#  ('103 west', 'roettelle a. g', 13),
#  ('103 west', 'roosevelt tamale parlor', 23),
#  ('103 west', 'rosa mexicano', 13),
#  ('103 west', "roscoe's house of chicken 'n' waffles", 36),
#  ('103 west', 'rose of india', 13),
#  ('103 west', 'rose pistola', 12),
#  ('103 west', 'rubicon', 8),
#  ('103 west', "rubin's red hots", 15),
#  ('103 west', "ruby's (la)", 11),
#  ('103 west', 'rumpus', 8),
#  ('103 west', "russell's burgers", 17),
#  ('103 west', "ruth's chris", 12),
#  ('103 west', "ruth's chris steak house (los angeles)", 38),
#  ('103 west', 's.p.q.r', 8),
#  ('103 west', 'sa tsu ki', 9),
#  ('103 west', "sal anthony's", 12),
#  ('103 west', "sally's cafe & bakery", 20),
#  ('103 west', "sam's noodle shop", 17),
#  ('103 west', "sammy's roumanian steak house", 28),
#  ('103 west', 'san domenico', 11),
#  ('103 west', 'san francisco bbq', 16),
#  ('103 west', 'san pietro', 8),
#  ('103 west', 'sanppo', 8),
#  ('103 west', 'sant ambroeus', 13),
#  ('103 west', "sarabeth's", 9),
#  ('103 west', "sarabeth's kitchen", 17),
#  ('103 west', 'sato sushi and thai', 19),
#  ('103 west', "scala's bistro", 13),
#  ('103 west', 'schatzi on main', 15),
#  ('103 west', 'sea grill', 8),
#  ('103 west', 'second avenue deli', 18),
#  ('103 west', 'second street grill', 19),
#  ('103 west', 'second street grille', 20),
#  ('103 west', 'serendipity', 11),
#  ('103 west', 'seryna', 8),
#  ('103 west', 'seventh regiment mess and bar', 29),
#  ('103 west', 'sfuzzi', 8),
#  ('103 west', 'shaan', 8),
#  ('103 west', 'shiro', 8),
#  ('103 west', 'shun lee palace', 15),
#  ('103 west', 'shun lee west', 13),
#  ('103 west', 'sign of the dove', 16),
#  ('103 west', 'silver skillet  the', 19),
#  ('103 west', 'slanted door', 11),
#  ('103 west', 'smith & wollensky', 17),
#  ('103 west', 'sofi', 8),
#  ('103 west', 'sofia fabulous pizza', 20),
#  ('103 west', 'soto', 8),
#  ('103 west', 'south city kitchen', 18),
#  ('103 west', 'south of france', 15),
#  ('103 west', 'south park cafe', 15),
#  ('103 west', 'spago', 8),
#  ('103 west', 'spago (las vegas)', 17),
#  ('103 west', 'spago (los angeles)', 19),
#  ('103 west', 'sparks steak house', 18),
#  ('103 west', 'splendido embarcadero', 21),
#  ('103 west', 'spring street natural restaurant & bar', 38),
#  ('103 west', 'stage deli', 10),
#  ('103 west', 'stars', 8),
#  ('103 west', 'stars cafe', 10),
#  ('103 west', 'steak house', 11),
#  ('103 west', 'steak house  the', 16),
#  ('103 west', 'steakhouse  the', 15),
#  ('103 west', "stefano's", 9),
#  ('103 west', 'sterling brunch', 15),
#  ('103 west', 'stick to your ribs', 18),
#  ('103 west', 'stingray', 8),
#  ('103 west', "stoyanof's cafe", 15),
#  ('103 west', 'straits cafe', 11),
#  ('103 west', "stringer's fish camp and oyster bar", 35),
#  ('103 west', 'sundown cafe', 12),
#  ('103 west', 'suppenkuche', 11),
#  ('103 west', 'sushi nozawa', 12),
#  ('103 west', 'sushisay', 8),
#  ('103 west', 'swan oyster depot', 17),
#  ('103 west', 'sweet lady jane', 15),
#  ('103 west', "sweet'n'tart cafe", 17),
#  ('103 west', 'swingers', 7),
#  ('103 west', "sylvia's", 8),
#  ('103 west', 'szechuan hunan cottage', 22),
#  ('103 west', 'szechuan kitchen', 16),
#  ('103 west', 't salon', 8),
#  ('103 west', 'tadich grill', 12),
#  ('103 west', 'taiko', 8),
#  ('103 west', 'tang pavillion', 14),
#  ('103 west', 'tapika', 8),
#  ('103 west', 'taste of new orleans', 20),
#  ('103 west', 'tavern on the green', 19),
#  ('103 west', 'tavola calda', 12),
#  ('103 west', "teresa's", 8),
#  ('103 west', 'terrace', 8),
#  ('103 west', 'thai house cafe', 15),
#  ('103 west', 'thailand restaurant', 19),
#  ('103 west', 'the bacchanal', 12),
#  ('103 west', 'the coffee pot', 13),
#  ('103 west', 'the heights', 9),
#  ('103 west', 'the mandarin', 11),
#  ('103 west', 'the palm', 7),
#  ('103 west', 'the savannah club', 16),
#  ('103 west', "thelma's kitchen", 16),
#  ('103 west', 'thep phanom', 11),
#  ('103 west', 'thepin', 8),
#  ('103 west', 'ti couz', 8),
#  ('103 west', 'tillerman', 9),
#  ('103 west', 'tillerman  the', 14),
#  ('103 west', "tommy tang's", 12),
#  ('103 west', "tommy's", 7),
#  ('103 west', 'tomtom', 8),
#  ('103 west', 'ton kiang', 8),
#  ('103 west', 'tortillas', 9),
#  ('103 west', 'toulouse', 7),
#  ('103 west', 'tra di noi', 9),
#  ('103 west', "trader vic's", 12),
#  ('103 west', "trattoria dell'arte", 19),
#  ('103 west', 'tre visi', 6),
#  ('103 west', 'triangolo', 9),
#  ('103 west', 'tribeca grill', 13),
#  ('103 west', 'trio cafe', 9),
#  ('103 west', 'trois jean', 10),
#  ('103 west', 'tse yang', 7),
#  ('103 west', 'tu lan', 8),
#  ('103 west', 'turkish kitchen', 15),
#  ('103 west', 'two two two', 10),
#  ('103 west', "uncle bill's pancake house", 26),
#  ('103 west', "uncle nick's", 12),
#  ('103 west', 'union square cafe', 16),
#  ('103 west', 'valentino', 9),
#  ('103 west', "van gogh's restaurant & bar", 26),
#  ('103 west', 'veggieland', 9),
#  ('103 west', 'venetian', 8),
#  ('103 west', 'veni vidi vici', 14),
#  ('103 west', "veniero's pasticceria", 21),
#  ('103 west', 'verbena', 8),
#  ('103 west', 'vertigo', 8),
#  ('103 west', 'veselka', 8),
#  ('103 west', 'vicolo pizzeria', 15),
#  ('103 west', "victor's cafe", 13),
#  ('103 west', 'vida', 8),
#  ('103 west', "vince & eddie's", 15),
#  ('103 west', "virgil's", 8),
#  ('103 west', "virgil's real bbq", 17),
#  ('103 west', "viva mercado's", 14),
#  ('103 west', 'vivande porta via', 17),
#  ('103 west', 'vivande ristorante', 18),
#  ('103 west', 'vong', 8),
#  ('103 west', 'wa-ha-ka oaxaca mexican grill', 29),
#  ('103 west', 'water club', 10),
#  ('103 west', 'water grill', 11),
#  ('103 west', 'west', 8),
#  ('103 west', 'west beach cafe', 15),
#  ('103 west', 'westside cottage', 16),
#  ('103 west', 'white house restaurant', 22),
#  ('103 west', 'windows on the world', 19),
#  ('103 west', "wollensky's grill", 16),
#  ('103 west', 'world wrapps', 12),
#  ('103 west', 'wu kong', 8),
#  ('103 west', 'xunta', 8),
#  ('103 west', 'yama', 8),
#  ('103 west', 'yank sing', 9),
#  ('103 west', 'yaya cuisine', 12),
#  ('103 west', "yolie's", 7),
#  ('103 west', 'yoyo tsumami bistro', 18),
#  ('103 west', "yujean kang's", 13),
#  ('103 west', "yujean kang's gourmet chinese cuisine", 37),
#  ('103 west', 'zab-e-lee', 9),
#  ('103 west', 'zankou chicken', 14),
#  ('103 west', 'zarela', 8),
#  ('103 west', 'zarzuela', 7),
#  ('103 west', 'zen palate', 9),
#  ('103 west', 'zoe', 8),
#  ('103 west', 'zuni cafe & grill', 17),
#  ('20 mott', '103 west', 7),
#  ('20 mott', '20 mott', 0),
#  ('20 mott', '21 club', 5),
#  ('20 mott', '2223', 6),
#  ('20 mott', '9 jones street', 14),
#  ('20 mott', 'abbey', 7),
#  ('20 mott', 'abruzzi', 7),
#  ('20 mott', 'acquarello', 10),
#  ('20 mott', "adriano's ristorante", 20),
#  ('20 mott', 'adrienne', 8),
#  ('20 mott', 'afghan kebab house', 18),
#  ('20 mott', 'agrotikon', 9),
#  ('20 mott', 'aja', 7),
#  ('20 mott', 'alain rondelli', 14),
#  ('20 mott', 'alamo', 5),
#  ('20 mott', "aleck's barbecue heaven", 23),
#  ('20 mott', "alley's end", 11),
#  ('20 mott', "alon's at the terrace", 21),
#  ('20 mott', 'ambassador grill', 16),
#  ('20 mott', 'american place', 14),
#  ('20 mott', 'anche vivolo', 12),
#  ('20 mott', "andre's french restaurant", 25),
#  ('20 mott', "annie's thai castle", 19),
#  ('20 mott', 'anthonys', 7),
#  ('20 mott', "antonio's", 9),
#  ('20 mott', 'apple pan  the', 14),
#  ('20 mott', 'aqua', 7),
#  ('20 mott', 'aquavit', 6),
#  ('20 mott', 'arcadia', 7),
#  ('20 mott', 'arizona', 6),
#  ('20 mott', "arnie morton's of chicago", 25),
#  ('20 mott', "art's deli", 10),
#  ('20 mott', "art's delicatessen", 18),
#  ('20 mott', "arturo's", 8),
#  ('20 mott', 'asahi ramen', 11),
#  ('20 mott', 'atlanta fish market', 18),
#  ('20 mott', 'au mandarin', 9),
#  ('20 mott', 'aureole', 6),
#  ('20 mott', 'bacchanalia', 11),
#  ('20 mott', 'baja fresh', 10),
#  ('20 mott', "baker's cajun cafe", 18),
#  ('20 mott', "bally's big kitchen", 19),
#  ('20 mott', 'bamboo garden', 12),
#  ('20 mott', 'bar anise', 9),
#  ('20 mott', 'barbecue kitchen', 16),
#  ('20 mott', 'barbetta', 6),
#  ('20 mott', "bardelli's", 10),
#  ('20 mott', 'barney greengrass', 17),
#  ('20 mott', "battista's hole in the wall", 26),
#  ('20 mott', 'beaurivage', 10),
#  ('20 mott', "beesley's of buckhead", 21),
#  ('20 mott', 'bel-air hotel', 13),
#  ('20 mott', 'belvedere  the', 14),
#  ('20 mott', "ben benson's", 12),
#  ('20 mott', "benita's frites", 15),
#  ('20 mott', "benny's burritos", 16),
#  ('20 mott', "bernard's", 9),
#  ('20 mott', "bertolini's", 10),
#  ('20 mott', 'betelnut', 8),
#  ('20 mott', 'big cup', 7),
#  ('20 mott', "bill's place", 12),
#  ('20 mott', "billy's", 7),
#  ('20 mott', "binion's coffee shop", 19),
#  ('20 mott', 'bistango', 8),
#  ('20 mott', 'bistro', 7),
#  ('20 mott', 'bistro  the', 11),
#  ('20 mott', 'bistro 45', 9),
#  ('20 mott', 'bistro garden', 13),
#  ('20 mott', 'bistro roti', 11),
#  ('20 mott', 'bix', 7),
#  ('20 mott', 'bizou', 7),
#  ('20 mott', "bobby & june's kountry kitchen", 30),
#  ('20 mott', 'boca chica', 10),
#  ('20 mott', 'bolo', 7),
#  ('20 mott', "bone's", 7),
#  ('20 mott', "bone's restaurant", 17),
#  ('20 mott', 'boonthai', 8),
#  ('20 mott', 'border grill', 12),
#  ('20 mott', 'boulevard', 9),
#  ('20 mott', 'bouterin', 8),
#  ('20 mott', "bradshaw's restaurant", 21),
#  ('20 mott', 'brasserie le coze', 17),
#  ('20 mott', "brent's deli", 12),
#  ('20 mott', 'brighton coffee shop', 19),
#  ('20 mott', 'bristol farms market cafe', 25),
#  ('20 mott', 'broadway deli', 13),
#  ('20 mott', 'broiler', 7),
#  ('20 mott', 'brookhaven cafe', 15),
#  ('20 mott', 'brothers bar-b-q', 16),
#  ('20 mott', 'bruno', 6),
#  ('20 mott', "bruno's", 6),
#  ('20 mott', 'bryant park grill  roof restaurant and bp cafe', 45),
#  ('20 mott', 'buca giovanni', 13),
#  ('20 mott', 'buccaneer bay club', 18),
#  ('20 mott', 'buckhead diner', 14),
#  ('20 mott', "bugsy's diner", 13),
#  ('20 mott', "buzio's in the rio", 17),
#  ('20 mott', 'c3', 7),
#  ('20 mott', "ca'brea", 7),
#  ('20 mott', "ca'del sol", 10),
#  ('20 mott', 'cafe  ritz-carlton  buckhead', 28),
#  ('20 mott', "cafe '50s", 9),
#  ('20 mott', 'cafe adriano', 12),
#  ('20 mott', 'cafe bianco', 11),
#  ('20 mott', 'cafe bizou', 10),
#  ('20 mott', 'cafe blanc', 10),
#  ('20 mott', 'cafe botanica', 13),
#  ('20 mott', 'cafe centro', 11),
#  ('20 mott', 'cafe claude', 11),
#  ('20 mott', 'cafe con leche', 14),
#  ('20 mott', 'cafe des artistes', 17),
#  ('20 mott', 'cafe fes', 8),
#  ('20 mott', 'cafe flore', 10),
#  ('20 mott', 'cafe la fortuna', 15),
#  ('20 mott', 'cafe lalo', 9),
#  ('20 mott', 'cafe luxembourg', 15),
#  ('20 mott', 'cafe marimba', 12),
#  ('20 mott', 'cafe michelle', 13),
#  ('20 mott', 'cafe pierre', 11),
#  ('20 mott', 'cafe pinot', 10),
#  ('20 mott', 'cafe renaissance', 16),
#  ('20 mott', 'cafe roma', 9),
#  ('20 mott', 'cafe sunflower', 14),
#  ('20 mott', 'caffe bondi ristorante', 22),
#  ('20 mott', 'caffe dante', 11),
#  ('20 mott', "caffe dell'artista", 18),
#  ('20 mott', 'caffe greco', 11),
#  ('20 mott', 'caffe lure', 10),
#  ('20 mott', 'caffe reggio', 12),
#  ('20 mott', 'caffe roma', 10),
#  ('20 mott', 'caffe vivaldi', 13),
#  ('20 mott', 'california culinary academy', 27),
#  ('20 mott', 'california pizza kitchen', 24),
#  ('20 mott', "camille's", 9),
#  ('20 mott', 'campanile', 9),
#  ('20 mott', 'campo santo', 10),
#  ('20 mott', 'campton place', 13),
#  ('20 mott', 'canoe', 7),
#  ('20 mott', "canter's", 8),
#  ('20 mott', "capozzoli's", 11),
#  ('20 mott', "capp's corner", 13),
#  ('20 mott', 'capsouto freres', 13),
#  ('20 mott', "captain's table", 15),
#  ('20 mott', "carey's", 7),
#  ('20 mott', "carey's corner", 14),
#  ('20 mott', "carmine's", 8),
#  ('20 mott', 'carnegie deli', 13),
#  ('20 mott', 'carnival world', 14),
#  ('20 mott', 'carta', 7),
#  ('20 mott', 'casa la femme', 13),
#  ('20 mott', "cassell's", 9),
#  ('20 mott', 'cassis', 7),
#  ('20 mott', 'cava', 7),
#  ('20 mott', 'cendrillon asian grill & marimba bar', 36),
#  ('20 mott', 'center stage plaza hotel', 24),
#  ('20 mott', 'cha cha cha', 11),
#  ('20 mott', "cha cha cha's", 13),
#  ('20 mott', 'chan dara', 9),
#  ('20 mott', 'chanterelle', 11),
#  ('20 mott', 'chevys', 7),
#  ('20 mott', 'chez jacqueline', 15),
#  ('20 mott', 'chez melange', 12),
#  ('20 mott', 'chez michel', 11),
#  ('20 mott', 'chiam', 7),
#  ('20 mott', "chin's", 7),
#  ('20 mott', 'china grill', 11),
#  ('20 mott', 'chinois on main', 14),
#  ('20 mott', 'chops', 7),
#  ('20 mott', 'chopstix', 7),
#  ('20 mott', 'ciboulette', 10),
#  ('20 mott', 'ciboulette restaurant', 21),
#  ('20 mott', 'circus circus', 13),
#  ('20 mott', 'cite', 7),
#  ('20 mott', 'citrus', 7),
#  ('20 mott', 'city grill', 10),
#  ('20 mott', 'clearwater cafe', 15),
#  ('20 mott', 'coco loco', 9),
#  ('20 mott', 'coco pazzo', 10),
#  ('20 mott', 'colonnade restaurant', 20),
#  ('20 mott', 'columbus bakery', 15),
#  ('20 mott', 'corner bistro', 13),
#  ('20 mott', 'corrado cafe', 12),
#  ('20 mott', 'coyote cafe', 11),
#  ('20 mott', 'coyote cafe (las vegas)', 23),
#  ('20 mott', 'ct', 7),
#  ('20 mott', 'cucina della fontana', 20),
#  ('20 mott', 'cucina di pesce', 15),
#  ('20 mott', 'cupcake cafe', 12),
#  ('20 mott', 'cypress club', 12),
#  ('20 mott', 'da nico', 6),
#  ('20 mott', 'daniel', 7),
#  ('20 mott', "dante's down the hatch", 22),
#  ('20 mott', "dante's down the hatch  buckhead", 32),
#  ('20 mott', 'darbar', 7),
#  ('20 mott', 'dawat', 7),
#  ('20 mott', "deacon burton's soulfood restaurant", 34),
#  ('20 mott', 'dean & deluca', 13),
#  ('20 mott', 'delectables', 10),
#  ('20 mott', 'des alpes', 9),
#  ('20 mott', 'diaghilev', 9),
#  ('20 mott', 'dining room', 11),
#  ('20 mott', 'dining room  ritz-carlton  buckhead', 35),
#  ('20 mott', 'diva', 7),
#  ('20 mott', 'dive!', 7),
#  ('20 mott', 'dix et sept', 10),
#  ('20 mott', 'docks', 7),
#  ('20 mott', "doidge's", 8),
#  ('20 mott', "don antonio's", 12),
#  ('20 mott', "dottie's true blue cafe", 23),
#  ('20 mott', 'drago', 6),
#  ('20 mott', "drai's", 7),
#  ('20 mott', 'duane park cafe', 15),
#  ('20 mott', "duke's", 7),
#  ('20 mott', 'dusit thai', 9),
#  ('20 mott', 'dynasty room', 11),
#  ('20 mott', 'eats', 7),
#  ('20 mott', 'ebisu', 7),
#  ('20 mott', 'eclipse', 7),
#  ('20 mott', "ed debevic's", 11),
#  ('20 mott', 'edison cafe', 10),
#  ('20 mott', "ej's luncheonette", 17),
#  ('20 mott', 'el cholo', 7),
#  ('20 mott', "el teddy's", 9),
#  ('20 mott', 'elias corner', 12),
#  ...]

# %%
newlist = filter(lambda x: x[2] > 0 and x[2] < 10, list_d)
newlist = list(newlist)
newlist.sort(key = lambda x: x[2])
newlist
# Out:
# [('c3', 'ct', 1),
#  ('cava', 'nava', 1),
#  ('ct', 'c3', 1),
#  ('felix', 'fenix', 1),
#  ('fenix', 'felix', 1),
#  ('march', 'match', 1),
#  ('match', 'march', 1),
#  ('nava', 'cava', 1),
#  ('second street grill', 'second street grille', 1),
#  ('second street grille', 'second street grill', 1),
#  ('2223', 'r-23', 2),
#  ('bolo', 'lola', 2),
#  ('bolo', 'soto', 2),
#  ('bruno', "bruno's", 2),
#  ("bruno's", 'bruno', 2),
#  ('cafe bianco', 'cafe blanc', 2),
#  ('cafe blanc', 'cafe bianco', 2),
#  ("canter's", "langer's", 2),
#  ('cassis', 'pastis', 2),
#  ('cava', 'diva', 2),
#  ('cava', 'yama', 2),
#  ('cha cha cha', "cha cha cha's", 2),
#  ("cha cha cha's", 'cha cha cha', 2),
#  ('diva', 'cava', 2),
#  ('diva', 'dive!', 2),
#  ('diva', 'nava', 2),
#  ('diva', 'vida', 2),
#  ('dive!', 'diva', 2),
#  ('drago', 'prego', 2),
#  ('drago', 'spago', 2),
#  ('eats', 'katsu', 2),
#  ('feast', 'first', 2),
#  ('first', 'feast', 2),
#  ("jimmy's", "tommy's", 2),
#  ("joe's", "rae's", 2),
#  ('johnny rockets (at)', 'johnny rockets (la)', 2),
#  ('johnny rockets (la)', 'johnny rockets (at)', 2),
#  ('katsu', 'eats', 2),
#  ("langer's", "canter's", 2),
#  ('lola', 'bolo', 2),
#  ('lola', 'lulu', 2),
#  ('lulu', 'lola', 2),
#  ('nava', 'diva', 2),
#  ('nava', 'yama', 2),
#  ('palio', 'palm', 2),
#  ('palio', 'pamir', 2),
#  ('palm', 'palio', 2),
#  ('pamir', 'palio', 2),
#  ('pastis', 'cassis', 2),
#  ('patina', 'patria', 2),
#  ('patria', 'patina', 2),
#  ('prego', 'drago', 2),
#  ('r-23', '2223', 2),
#  ("rae's", "joe's", 2),
#  ('sofi', 'soto', 2),
#  ('soto', 'bolo', 2),
#  ('soto', 'sofi', 2),
#  ('spago', 'drago', 2),
#  ("tommy's", "jimmy's", 2),
#  ('vida', 'diva', 2),
#  ('yama', 'cava', 2),
#  ('yama', 'nava', 2),
#  ('aja', 'alamo', 3),
#  ('aja', 'aqua', 3),
#  ('aja', 'bix', 3),
#  ('aja', 'c3', 3),
#  ('aja', 'ct', 3),
#  ('aja', 'faz', 3),
#  ('aja', 'zoe', 3),
#  ('alamo', 'aja', 3),
#  ('alamo', 'drago', 3),
#  ('alamo', 'spago', 3),
#  ('aqua', 'aja', 3),
#  ('aqua', 'aquavit', 3),
#  ('aqua', 'cava', 3),
#  ('aqua', 'diva', 3),
#  ('aqua', 'lola', 3),
#  ('aqua', 'nava', 3),
#  ('aqua', 'vida', 3),
#  ('aqua', 'yama', 3),
#  ('aquavit', 'aqua', 3),
#  ("billy's", "emily's", 3),
#  ("billy's", "jimmy's", 3),
#  ('bistro', 'bistro 45', 3),
#  ('bistro 45', 'bistro', 3),
#  ('bix', 'aja', 3),
#  ('bix', 'bizou', 3),
#  ('bix', 'bolo', 3),
#  ('bix', 'c3', 3),
#  ('bix', 'cite', 3),
#  ('bix', 'ct', 3),
#  ('bix', 'diva', 3),
#  ('bix', 'faz', 3),
#  ('bix', 'kiev', 3),
#  ('bix', 'vida', 3),
#  ('bix', 'zoe', 3),
#  ('bizou', 'bix', 3),
#  ('bizou', 'bolo', 3),
#  ('bolo', 'bix', 3),
#  ('bolo', 'bizou', 3),
#  ('bolo', 'home', 3),
#  ('bolo', 'joss', 3),
#  ('bolo', 'lulu', 3),
#  ('bolo', 'nobu', 3),
#  ('bolo', 'orso', 3),
#  ('bolo', 'palm', 3),
#  ('bolo', 'sofi', 3),
#  ('bolo', 'vong', 3),
#  ('bolo', 'zoe', 3),
#  ("bone's", "duke's", 3),
#  ('bruno', 'drago', 3),
#  ('bruno', "l'udo", 3),
#  ('bruno', 'prego', 3),
#  ('c3', 'aja', 3),
#  ('c3', 'bix', 3),
#  ('c3', 'cava', 3),
#  ('c3', 'cite', 3),
#  ('c3', 'faz', 3),
#  ('c3', 'zoe', 3),
#  ('cafe bizou', 'cafe pinot', 3),
#  ('cafe pinot', 'cafe bizou', 3),
#  ('canoe', 'carta', 3),
#  ('canoe', 'cava', 3),
#  ('canoe', 'daniel', 3),
#  ('canoe', 'manora', 3),
#  ("carey's", "perry's", 3),
#  ('carta', 'canoe', 3),
#  ('carta', 'cava', 3),
#  ('carta', 'darbar', 3),
#  ('carta', 'layla', 3),
#  ('carta', 'march', 3),
#  ('carta', 'xunta', 3),
#  ('cassis', "masa's", 3),
#  ('cava', 'aqua', 3),
#  ('cava', 'c3', 3),
#  ('cava', 'canoe', 3),
#  ('cava', 'carta', 3),
#  ('cava', 'chiam', 3),
#  ('cava', 'cite', 3),
#  ('cava', 'ct', 3),
#  ('cava', 'dawat', 3),
#  ('cava', 'eats', 3),
#  ('cava', 'faz', 3),
#  ('cava', 'lola', 3),
#  ('cava', 'palm', 3),
#  ('cava', 'rain', 3),
#  ('cava', 'vida', 3),
#  ('chevys', "chin's", 3),
#  ('chiam', 'cava', 3),
#  ('chiam', "chin's", 3),
#  ('chiam', 'chops', 3),
#  ('chiam', 'shaan', 3),
#  ('chiam', 'shiro', 3),
#  ("chin's", 'chevys', 3),
#  ("chin's", 'chiam', 3),
#  ('chops', 'chiam', 3),
#  ('chops', 'chopstix', 3),
#  ('chopstix', 'chops', 3),
#  ('cite', 'bix', 3),
#  ('cite', 'c3', 3),
#  ('cite', 'cava', 3),
#  ('cite', 'citrus', 3),
#  ('cite', 'ct', 3),
#  ('cite', 'diva', 3),
#  ('cite', 'dive!', 3),
#  ('cite', 'eats', 3),
#  ('cite', 'home', 3),
#  ('cite', 'kiev', 3),
#  ('cite', 'soto', 3),
#  ('cite', 'vida', 3),
#  ('citrus', 'cite', 3),
#  ('ct', 'aja', 3),
#  ('ct', 'bix', 3),
#  ('ct', 'cava', 3),
#  ('ct', 'cite', 3),
#  ('ct', 'faz', 3),
#  ('ct', 'zoe', 3),
#  ('da nico', 'il nido', 3),
#  ('daniel', 'canoe', 3),
#  ('darbar', 'carta', 3),
#  ('dawat', 'cava', 3),
#  ('dawat', 'diva', 3),
#  ('dawat', 'nava', 3),
#  ('dawat', 'yama', 3),
#  ('diva', 'aqua', 3),
#  ('diva', 'bix', 3),
#  ('diva', 'cite', 3),
#  ('diva', 'dawat', 3),
#  ('diva', 'kiev', 3),
#  ('diva', 'lola', 3),
#  ('diva', 'yama', 3),
#  ('dive!', 'cite', 3),
#  ('docks', "joe's", 3),
#  ('drago', 'alamo', 3),
#  ('drago', 'bruno', 3),
#  ('drago', "drai's", 3),
#  ("drai's", 'drago', 3),
#  ("drai's", "duke's", 3),
#  ("duke's", "bone's", 3),
#  ("duke's", "drai's", 3),
#  ('eats', 'cava', 3),
#  ('eats', 'cite', 3),
#  ('eats', 'ebisu', 3),
#  ('eats', 'faz', 3),
#  ('eats', 'joss', 3),
#  ('eats', 'match', 3),
#  ('eats', 'nava', 3),
#  ('eats', 'palm', 3),
#  ('eats', 'rain', 3),
#  ('eats', 'soto', 3),
#  ('eats', 'yama', 3),
#  ('ebisu', 'eats', 3),
#  ('ebisu', 'katsu', 3),
#  ("emily's", "billy's", 3),
#  ("ernie's", "yolie's", 3),
#  ('faz', 'aja', 3),
#  ('faz', 'bix', 3),
#  ('faz', 'c3', 3),
#  ('faz', 'cava', 3),
#  ('faz', 'ct', 3),
#  ('faz', 'eats', 3),
#  ('faz', 'nava', 3),
#  ('faz', 'palm', 3),
#  ('faz', 'rain', 3),
#  ('faz', 'yama', 3),
#  ('faz', 'zoe', 3),
#  ('feast', 'felix', 3),
#  ('feast', 'fenix', 3),
#  ('felidia', 'felix', 3),
#  ('felix', 'feast', 3),
#  ('felix', 'felidia', 3),
#  ('felix', 'palio', 3),
#  ('felix', 'remi', 3),
#  ('fenix', 'feast', 3),
#  ('fenix', 'remi', 3),
#  ('girafe', 'jiraffe', 3),
#  ('home', 'bolo', 3),
#  ('home', 'cite', 3),
#  ('home', 'joss', 3),
#  ('home', 'lola', 3),
#  ('home', 'nobu', 3),
#  ('home', 'remi', 3),
#  ('home', 'sofi', 3),
#  ('home', 'soto', 3),
#  ('home', 'vong', 3),
#  ('home', 'yama', 3),
#  ('home', 'zoe', 3),
#  ('il nido', 'da nico', 3),
#  ('inca grill', 'mesa grill', 3),
#  ('indo cafe', 'trio cafe', 3),
#  ("jack's", "masa's", 3),
#  ("jack's", "paty's", 3),
#  ("jimmy's", "billy's", 3),
#  ('jiraffe', 'girafe', 3),
#  ('jo jo', "joe's", 3),
#  ('jo jo', 'joss', 3),
#  ('jo jo', 'posto', 3),
#  ("joe's", 'docks', 3),
#  ("joe's", 'jo jo', 3),
#  ("joe's", 'joss', 3),
#  ("joe's", 'zoe', 3),
#  ('joss', 'bolo', 3),
#  ('joss', 'eats', 3),
#  ('joss', 'home', 3),
#  ('joss', 'jo jo', 3),
#  ('joss', "joe's", 3),
#  ('joss', 'lola', 3),
#  ('joss', 'nobu', 3),
#  ('joss', 'orso', 3),
#  ('joss', 'posto', 3),
#  ('joss', 'sofi', 3),
#  ('joss', 'soto', 3),
#  ('joss', 'vong', 3),
#  ('joss', 'west', 3),
#  ('joss', 'zoe', 3),
#  ('katsu', 'ebisu', 3),
#  ('katsu', 'match', 3),
#  ('kiev', 'bix', 3),
#  ('kiev', 'cite', 3),
#  ('kiev', 'diva', 3),
#  ('kiev', 'vida', 3),
#  ('kiev', 'zoe', 3),
#  ("l'udo", 'bruno', 3),
#  ('layla', 'carta', 3),
#  ('le jardin', 'le marais', 3),
#  ('le madri', 'le marais', 3),
#  ('le marais', 'le jardin', 3),
#  ('le marais', 'le madri', 3),
#  ('le select', 'le soleil', 3),
#  ('le soleil', 'le select', 3),
#  ('lola', 'aqua', 3),
#  ('lola', 'cava', 3),
#  ('lola', 'diva', 3),
#  ('lola', 'home', 3),
#  ('lola', 'joss', 3),
#  ('lola', 'nava', 3),
#  ('lola', 'nobu', 3),
#  ('lola', 'palm', 3),
#  ('lola', 'sofi', 3),
#  ('lola', 'soto', 3),
#  ('lola', 'vida', 3),
#  ('lola', 'vong', 3),
#  ('lola', 'yama', 3),
#  ('lola', 'zoe', 3),
#  ('lulu', 'bolo', 3),
#  ('lulu', 'nobu', 3),
#  ('lulu', 'palm', 3),
#  ('manora', 'canoe', 3),
#  ('march', 'carta', 3),
#  ("martha's", "morton's", 3),
#  ("masa's", 'cassis', 3),
#  ("masa's", "jack's", 3),
#  ("masa's", 'pastis', 3),
#  ("masa's", "paty's", 3),
#  ('match', 'eats', 3),
#  ('match', 'katsu', 3),
#  ('mesa grill', 'inca grill', 3),
#  ("moose's", "yolie's", 3),
#  ("morton's", "martha's", 3),
#  ('nava', 'aqua', 3),
#  ('nava', 'dawat', 3),
#  ('nava', 'eats', 3),
#  ('nava', 'faz', 3),
#  ('nava', 'lola', 3),
#  ('nava', 'nobu', 3),
#  ('nava', 'palm', 3),
#  ('nava', 'rain', 3),
#  ('nava', 'vida', 3),
#  ('nobu', 'bolo', 3),
#  ('nobu', 'home', 3),
#  ('nobu', 'joss', 3),
#  ('nobu', 'lola', 3),
#  ('nobu', 'lulu', 3),
#  ('nobu', 'nava', 3),
#  ('nobu', 'sofi', 3),
#  ('nobu', 'soto', 3),
#  ('nobu', 'vong', 3),
#  ('nobu', 'zoe', 3),
#  ('oceana', 'odeon', 3),
#  ('odeon', 'oceana', 3),
#  ('odeon', 'orso', 3),
#  ('orso', 'bolo', 3),
#  ('orso', 'joss', 3),
#  ('orso', 'odeon', 3),
#  ('orso', 'soto', 3),
#  ('orso', 'west', 3),
#  ('otabe', 'stars', 3),
#  ('palio', 'felix', 3),
#  ('palio', 'patina', 3),
#  ('palio', 'posto', 3),
#  ('palio', 'prego', 3),
#  ('palio', 'taiko', 3),
#  ('palm', 'bolo', 3),
#  ('palm', 'cava', 3),
#  ('palm', 'eats', 3),
#  ('palm', 'faz', 3),
#  ('palm', 'lola', 3),
#  ('palm', 'lulu', 3),
#  ('palm', 'nava', 3),
#  ('palm', 'pamir', 3),
#  ('palm', 'rain', 3),
#  ('palm', 'yama', 3),
#  ('pamir', 'palm', 3),
#  ('pamir', 'patina', 3),
#  ('pamir', 'remi', 3),
#  ('pamir', 'yama', 3),
#  ('pastis', "masa's", 3),
#  ('pastis', 'patria', 3),
#  ('pastis', "paty's", 3),
#  ('pastis', 'pisces', 3),
#  ('pastis', 'posto', 3),
#  ('patina', 'palio', 3),
#  ('patina', 'pamir', 3),
#  ('patina', "paty's", 3),
#  ('patina', 'tapika', 3),
#  ('patria', 'pastis', 3),
#  ('patria', "paty's", 3),
#  ("paty's", "jack's", 3),
#  ("paty's", "masa's", 3),
#  ("paty's", 'pastis', 3),
#  ("paty's", 'patina', 3),
#  ("paty's", 'patria', 3),
#  ("perry's", "carey's", 3),
#  ('pisces', 'pastis', 3),
#  ('posto', 'jo jo', 3),
#  ('posto', 'joss', 3),
#  ('posto', 'palio', 3),
#  ('posto', 'pastis', 3),
#  ('posto', 'postrio', 3),
#  ('posto', 'prego', 3),
#  ('posto', 'tomtom', 3),
#  ('posto', 'west', 3),
#  ('postrio', 'posto', 3),
#  ('prego', 'bruno', 3),
#  ('prego', 'palio', 3),
#  ('prego', 'posto', 3),
#  ('prego', 'spago', 3),
#  ('r-23', 'rain', 3),
#  ('r-23', 'remi', 3),
#  ("rae's", 'rain', 3),
#  ('rain', 'cava', 3),
#  ('rain', 'eats', 3),
#  ('rain', 'faz', 3),
#  ('rain', 'nava', 3),
#  ('rain', 'palm', 3),
#  ('rain', 'r-23', 3),
#  ('rain', "rae's", 3),
#  ('rain', 'remi', 3),
#  ('rain', 'taiko', 3),
#  ('rain', 'yama', 3),
#  ('remi', 'felix', 3),
#  ('remi', 'fenix', 3),
#  ('remi', 'home', 3),
#  ('remi', 'pamir', 3),
#  ('remi', 'r-23', 3),
#  ('remi', 'rain', 3),
#  ('remi', 'sofi', 3),
#  ('remi', 'west', 3),
#  ('remi', 'yama', 3),
#  ('shaan', 'chiam', 3),
#  ('shaan', 'shiro', 3),
#  ('shaan', 'spago', 3),
#  ('shaan', 'stars', 3),
#  ('shiro', 'chiam', 3),
#  ('shiro', 'shaan', 3),
#  ('shiro', 'spago', 3),
#  ('shiro', 'stars', 3),
#  ('shiro', 'taiko', 3),
#  ('sofi', 'bolo', 3),
#  ('sofi', 'home', 3),
#  ('sofi', 'joss', 3),
#  ('sofi', 'lola', 3),
#  ('sofi', 'nobu', 3),
#  ('sofi', 'remi', 3),
#  ('sofi', 'vong', 3),
#  ('sofi', 'zoe', 3),
#  ('soto', 'cite', 3),
#  ('soto', 'eats', 3),
#  ('soto', 'home', 3),
#  ('soto', 'joss', 3),
#  ('soto', 'lola', 3),
#  ('soto', 'nobu', 3),
#  ('soto', 'orso', 3),
#  ('soto', 'vong', 3),
#  ('soto', 'zoe', 3),
#  ('spago', 'alamo', 3),
#  ('spago', 'prego', 3),
#  ('spago', 'shaan', 3),
#  ('spago', 'shiro', 3),
#  ('spago', 'stars', 3),
#  ('stars', 'otabe', 3),
#  ('stars', 'shaan', 3),
#  ('stars', 'shiro', 3),
#  ('stars', 'spago', 3),
#  ('taiko', 'palio', 3),
#  ('taiko', 'rain', 3),
#  ('taiko', 'shiro', 3),
#  ('tapika', 'patina', 3),
#  ('tomtom', 'posto', 3),
#  ('trio cafe', 'indo cafe', 3),
#  ('vida', 'aqua', 3),
#  ('vida', 'bix', 3),
#  ('vida', 'cava', 3),
#  ('vida', 'cite', 3),
#  ('vida', 'kiev', 3),
#  ('vida', 'lola', 3),
#  ('vida', 'nava', 3),
#  ('vida', 'vong', 3),
#  ('vida', 'yama', 3),
#  ('vong', 'bolo', 3),
#  ('vong', 'home', 3),
#  ('vong', 'joss', 3),
#  ('vong', 'lola', 3),
#  ('vong', 'nobu', 3),
#  ('vong', 'sofi', 3),
#  ('vong', 'soto', 3),
#  ('vong', 'vida', 3),
#  ('vong', 'zoe', 3),
#  ('west', 'joss', 3),
#  ('west', 'orso', 3),
#  ('west', 'posto', 3),
#  ('west', 'remi', 3),
#  ('xunta', 'carta', 3),
#  ('yama', 'aqua', 3),
#  ('yama', 'dawat', 3),
#  ('yama', 'diva', 3),
#  ('yama', 'eats', 3),
#  ('yama', 'faz', 3),
#  ('yama', 'home', 3),
#  ('yama', 'lola', 3),
#  ('yama', 'palm', 3),
#  ('yama', 'pamir', 3),
#  ('yama', 'rain', 3),
#  ('yama', 'remi', 3),
#  ('yama', 'vida', 3),
#  ("yolie's", "ernie's", 3),
#  ("yolie's", "moose's", 3),
#  ('zoe', 'aja', 3),
#  ('zoe', 'bix', 3),
#  ('zoe', 'bolo', 3),
#  ('zoe', 'c3', 3),
#  ('zoe', 'ct', 3),
#  ('zoe', 'faz', 3),
#  ('zoe', 'home', 3),
#  ('zoe', "joe's", 3),
#  ('zoe', 'joss', 3),
#  ('zoe', 'kiev', 3),
#  ('zoe', 'lola', 3),
#  ('zoe', 'nobu', 3),
#  ('zoe', 'sofi', 3),
#  ('zoe', 'soto', 3),
#  ('zoe', 'vong', 3),
#  ('21 club', 'ti couz', 4),
#  ('2223', 'aja', 4),
#  ('2223', 'aqua', 4),
#  ('2223', 'bix', 4),
#  ('2223', 'bolo', 4),
#  ('2223', 'c3', 4),
#  ('2223', 'cava', 4),
#  ('2223', 'cite', 4),
#  ('2223', 'ct', 4),
#  ('2223', 'diva', 4),
#  ('2223', 'eats', 4),
#  ('2223', 'faz', 4),
#  ('2223', 'home', 4),
#  ('2223', 'joss', 4),
#  ('2223', 'kiev', 4),
#  ('2223', 'lola', 4),
#  ('2223', 'lulu', 4),
#  ('2223', 'nava', 4),
#  ('2223', 'nobu', 4),
#  ('2223', 'orso', 4),
#  ('2223', 'palm', 4),
#  ('2223', 'rain', 4),
#  ('2223', 'remi', 4),
#  ('2223', 'sofi', 4),
#  ('2223', 'soto', 4),
#  ('2223', 'vida', 4),
#  ('2223', 'vong', 4),
#  ('2223', 'west', 4),
#  ('2223', 'yama', 4),
#  ('2223', 'zoe', 4),
#  ('abbey', 'aja', 4),
#  ('abbey', 'alamo', 4),
#  ('abbey', 'aqua', 4),
#  ('abbey', 'cite', 4),
#  ('abbey', 'dive!', 4),
#  ('abbey', 'ebisu', 4),
#  ('abbey', 'home', 4),
#  ('abbey', 'nobu', 4),
#  ('aja', '2223', 4),
#  ('aja', 'abbey', 4),
#  ('aja', 'bolo', 4),
#  ('aja', 'cava', 4),
#  ('aja', 'cite', 4),
#  ('aja', 'diva', 4),
#  ('aja', 'drago', 4),
#  ('aja', 'eats', 4),
#  ('aja', 'feast', 4),
#  ('aja', 'home', 4),
#  ('aja', 'joss', 4),
#  ('aja', 'kiev', 4),
#  ('aja', 'lola', 4),
#  ('aja', 'lulu', 4),
#  ('aja', 'nava', 4),
#  ('aja', 'nobu', 4),
#  ('aja', 'orso', 4),
#  ('aja', 'otabe', 4),
#  ('aja', 'palm', 4),
#  ('aja', 'r-23', 4),
#  ('aja', 'rain', 4),
#  ('aja', 'remi', 4),
#  ('aja', 'shaan', 4),
#  ('aja', 'sofi', 4),
#  ('aja', 'soto', 4),
#  ('aja', 'spago', 4),
#  ('aja', 'stars', 4),
#  ('aja', 'vida', 4),
#  ('aja', 'vong', 4),
#  ('aja', 'west', 4),
#  ('aja', 'yama', 4),
#  ('alamo', 'abbey', 4),
#  ('alamo', 'aqua', 4),
#  ('alamo', 'bruno', 4),
#  ('alamo', 'feast', 4),
#  ('alamo', 'jo jo', 4),
#  ('alamo', "l'udo", 4),
#  ('alamo', 'otabe', 4),
#  ('alamo', 'palio', 4),
#  ('alamo', 'palm', 4),
#  ('alamo', 'posto', 4),
#  ('alamo', 'prego', 4),
#  ('alamo', 'shaan', 4),
#  ('alamo', 'shiro', 4),
#  ('alamo', 'stars', 4),
#  ('alamo', 'taiko', 4),
#  ('aqua', '2223', 4),
#  ('aqua', 'abbey', 4),
#  ('aqua', 'alamo', 4),
#  ('aqua', 'bix', 4),
#  ('aqua', 'bolo', 4),
#  ('aqua', 'bruno', 4),
#  ('aqua', 'c3', 4),
#  ('aqua', 'chiam', 4),
#  ('aqua', 'cite', 4),
#  ('aqua', 'ct', 4),
#  ('aqua', 'dawat', 4),
#  ('aqua', 'eats', 4),
#  ('aqua', 'faz', 4),
#  ('aqua', 'home', 4),
#  ('aqua', 'joss', 4),
#  ('aqua', 'kiev', 4),
#  ('aqua', "l'udo", 4),
#  ('aqua', 'lulu', 4),
#  ('aqua', 'nobu', 4),
#  ('aqua', 'orso', 4),
#  ('aqua', 'palm', 4),
#  ('aqua', 'r-23', 4),
#  ('aqua', 'rain', 4),
#  ('aqua', 'remi', 4),
#  ('aqua', 'shaan', 4),
#  ('aqua', 'sofi', 4),
#  ('aqua', 'soto', 4),
#  ('aqua', 'vong', 4),
#  ('aqua', 'west', 4),
#  ('aqua', 'zoe', 4),
#  ('aquavit', 'arcadia', 4),
#  ('arcadia', 'aquavit', 4),
#  ('arcadia', 'arizona', 4),
#  ('arcadia', 'felidia', 4),
#  ('arizona', 'arcadia', 4),
#  ('bamboo garden', 'bistro garden', 4),
#  ('bar anise', 'campanile', 4),
#  ("billy's", "bruno's", 4),
#  ("billy's", "carey's", 4),
#  ("billy's", "perry's", 4),
#  ("billy's", "tommy's", 4),
#  ("billy's", "yolie's", 4),
#  ('bistango', 'bistro', 4),
#  ('bistro', 'bistango', 4),
#  ('bistro', 'bix', 4),
#  ('bistro', 'bizou', 4),
#  ('bistro', 'mikado', 4),
#  ('bistro', 'pastis', 4),
#  ('bistro', 'pisces', 4),
#  ('bistro', 'posto', 4),
#  ('bistro', 'postrio', 4),
#  ('bistro', 'west', 4),
#  ('bistro  the', 'bistro 45', 4),
#  ('bistro  the', 'bistro roti', 4),
#  ('bistro 45', 'bistro  the', 4),
#  ('bistro 45', 'bistro roti', 4),
#  ('bistro garden', 'bamboo garden', 4),
#  ('bistro roti', 'bistro  the', 4),
#  ('bistro roti', 'bistro 45', 4),
#  ('bix', '2223', 4),
#  ('bix', 'aqua', 4),
#  ('bix', 'bistro', 4),
#  ('bix', 'bruno', 4),
#  ('bix', 'cava', 4),
#  ('bix', 'dive!', 4),
#  ('bix', 'eats', 4),
#  ('bix', 'first', 4),
#  ('bix', 'home', 4),
#  ('bix', 'joss', 4),
#  ('bix', 'lola', 4),
#  ('bix', 'lulu', 4),
#  ('bix', 'nava', 4),
#  ('bix', 'nobu', 4),
#  ('bix', 'orso', 4),
#  ('bix', 'palm', 4),
#  ('bix', 'r-23', 4),
#  ('bix', 'rain', 4),
#  ('bix', 'remi', 4),
#  ('bix', 'sofi', 4),
#  ('bix', 'soto', 4),
#  ('bix', 'vong', 4),
#  ('bix', 'west', 4),
#  ('bix', 'yama', 4),
#  ('bizou', 'bistro', 4),
#  ('bizou', 'bruno', 4),
#  ('bizou', 'canoe', 4),
#  ('bizou', 'cite', 4),
#  ('bizou', 'citrus', 4),
#  ('bizou', 'diva', 4),
#  ('bizou', 'dive!', 4),
#  ('bizou', 'ebisu', 4),
#  ('bizou', 'faz', 4),
#  ('bizou', 'first', 4),
#  ('bizou', 'katsu', 4),
#  ('bizou', 'kiev', 4),
#  ('bizou', 'nicola', 4),
#  ('bizou', 'odeon', 4),
#  ('bizou', 'orso', 4),
#  ('bizou', 'soto', 4),
#  ('bizou', 'vida', 4),
#  ('bolo', '2223', 4),
#  ('bolo', 'aja', 4),
#  ('bolo', 'aqua', 4),
#  ('bolo', "bone's", 4),
#  ('bolo', 'bruno', 4),
#  ('bolo', 'c3', 4),
#  ('bolo', 'canoe', 4),
#  ('bolo', 'cava', 4),
#  ('bolo', 'cite', 4),
#  ('bolo', 'ct', 4),
#  ('bolo', 'diva', 4),
#  ('bolo', 'docks', 4),
#  ('bolo', 'eats', 4),
#  ('bolo', 'faz', 4),
#  ('bolo', 'felix', 4),
#  ('bolo', 'jo jo', 4),
#  ('bolo', "joe's", 4),
#  ('bolo', 'kiev', 4),
#  ('bolo', 'nava', 4),
#  ('bolo', 'odeon', 4),
#  ('bolo', 'palio', 4),
#  ('bolo', 'posto', 4),
#  ('bolo', 'r-23', 4),
#  ('bolo', 'rain', 4),
#  ('bolo', 'remi', 4),
#  ('bolo', 'vida', 4),
#  ('bolo', 'west', 4),
#  ('bolo', 'yama', 4),
#  ("bone's", 'bolo', 4),
#  ("bone's", "chin's", 4),
#  ("bone's", "drai's", 4),
#  ("bone's", 'greens', 4),
#  ("bone's", 'home', 4),
#  ("bone's", "jack's", 4),
#  ("bone's", "masa's", 4),
#  ("bone's", "paty's", 4),
#  ("bone's", 'vong', 4),
#  ('bruno', 'alamo', 4),
#  ('bruno', 'aqua', 4),
#  ('bruno', 'bix', 4),
#  ('bruno', 'bizou', 4),
#  ('bruno', 'bolo', 4),
#  ('bruno', 'jo jo', 4),
#  ('bruno', 'orso', 4),
#  ('bruno', 'palio', 4),
#  ('bruno', 'posto', 4),
#  ('bruno', 'rain', 4),
#  ('bruno', 'shiro', 4),
#  ('bruno', 'spago', 4),
#  ('bruno', 'taiko', 4),
#  ("bruno's", "billy's", 4),
#  ("bruno's", "ernie's", 4),
#  ('c3', '2223', 4),
#  ('c3', 'aqua', 4),
#  ('c3', 'bolo', 4),
#  ('c3', 'canoe', 4),
#  ('c3', 'carta', 4),
#  ('c3', 'chiam', 4),
#  ('c3', 'chops', 4),
#  ('c3', 'diva', 4),
#  ('c3', 'eats', 4),
#  ('c3', 'home', 4),
#  ('c3', 'joss', 4),
#  ('c3', 'kiev', 4),
#  ('c3', 'lola', 4),
#  ('c3', 'lulu', 4),
#  ('c3', 'nava', 4),
#  ('c3', 'nobu', 4),
#  ('c3', 'orso', 4),
#  ('c3', 'palm', 4),
#  ('c3', 'r-23', 4),
#  ('c3', 'rain', 4),
#  ('c3', 'remi', 4),
#  ('c3', 'sofi', 4),
#  ('c3', 'soto', 4),
#  ('c3', 'vida', 4),
#  ('c3', 'vong', 4),
#  ('c3', 'west', 4),
#  ('c3', 'yama', 4),
#  ("cafe '50s", 'cafe fes', 4),
#  ("cafe '50s", 'cafe lalo', 4),
#  ("cafe '50s", 'cafe roma', 4),
#  ('cafe bianco', 'cafe bizou', 4),
#  ('cafe bizou', 'cafe bianco', 4),
#  ('cafe bizou', 'cafe blanc', 4),
#  ('cafe bizou', 'cafe lalo', 4),
#  ('cafe blanc', 'cafe bizou', 4),
#  ('cafe blanc', 'cafe claude', 4),
#  ('cafe blanc', 'cafe flore', 4),
#  ('cafe claude', 'cafe blanc', 4),
#  ('cafe fes', "cafe '50s", 4),
#  ('cafe fes', 'cafe flore', 4),
#  ('cafe fes', 'cafe lalo', 4),
#  ('cafe fes', 'cafe roma', 4),
#  ('cafe flore', 'cafe blanc', 4),
#  ('cafe flore', 'cafe fes', 4),
#  ('cafe flore', 'caffe lure', 4),
#  ('cafe lalo', "cafe '50s", 4),
#  ('cafe lalo', 'cafe bizou', 4),
#  ('cafe lalo', 'cafe fes', 4),
#  ('cafe lalo', 'cafe pinot', 4),
#  ('cafe lalo', 'cafe roma', 4),
#  ('cafe pierre', 'cafe pinot', 4),
#  ('cafe pinot', 'cafe lalo', 4),
#  ('cafe pinot', 'cafe pierre', 4),
#  ('cafe roma', "cafe '50s", 4),
#  ('cafe roma', 'cafe fes', 4),
#  ('cafe roma', 'cafe lalo', 4),
#  ('caffe lure', 'cafe flore', 4),
#  ('caffe lure', 'caffe roma', 4),
#  ('caffe roma', 'caffe lure', 4),
#  ("camille's", "carmine's", 4),
#  ("camille's", "cassell's", 4),
#  ('campanile', 'bar anise', 4),
#  ('canoe', 'bizou', 4),
#  ('canoe', 'bolo', 4),
#  ('canoe', 'c3', 4),
#  ('canoe', "canter's", 4),
#  ('canoe', 'cassis', 4),
#  ('canoe', 'chiam', 4),
#  ('canoe', 'chops', 4),
#  ('canoe', 'cite', 4),
#  ('canoe', 'ct', 4),
#  ('canoe', 'dawat', 4),
#  ('canoe', 'eats', 4),
#  ('canoe', 'faz', 4),
#  ('canoe', 'fenix', 4),
#  ('canoe', 'katsu', 4),
#  ('canoe', 'layla', 4),
#  ('canoe', 'march', 4),
#  ('canoe', 'match', 4),
#  ('canoe', 'nava', 4),
#  ('canoe', 'odeon', 4),
#  ('canoe', 'orso', 4),
#  ('canoe', 'otabe', 4),
#  ('canoe', 'palio', 4),
#  ('canoe', 'palm', 4),
#  ('canoe', 'pamir', 4),
#  ('canoe', "rae's", 4),
#  ('canoe', 'rain', 4),
#  ('canoe', 'sanppo', 4),
#  ('canoe', 'soto', 4),
#  ('canoe', 'taiko', 4),
#  ('canoe', 'vong', 4),
#  ('canoe', 'xunta', 4),
#  ('canoe', 'yama', 4),
#  ("canter's", 'canoe', 4),
#  ("canter's", "martha's", 4),
#  ("carey's", "billy's", 4),
#  ("carey's", 'carta', 4),
#  ("carey's", "emily's", 4),
#  ("carey's", "jimmy's", 4),
#  ("carey's", "katia's", 4),
#  ("carey's", "tommy's", 4),
#  ("carey's", 'zarela', 4),
#  ("carmine's", "camille's", 4),
#  ('carta', 'c3', 4),
#  ('carta', "carey's", 4),
#  ('carta', 'cassis', 4),
#  ('carta', 'chiam', 4),
#  ('carta', 'chops', 4),
#  ('carta', 'cite', 4),
#  ('carta', 'ct', 4),
#  ('carta', 'dawat', 4),
#  ('carta', 'eats', 4),
#  ('carta', 'faz', 4),
#  ('carta', 'first', 4),
#  ('carta', 'katsu', 4),
#  ('carta', 'match', 4),
#  ('carta', 'nava', 4),
#  ('carta', 'palio', 4),
#  ('carta', 'palm', 4),
#  ('carta', 'pamir', 4),
#  ('carta', 'pastis', 4),
#  ('carta', 'posto', 4),
#  ('carta', "rae's", 4),
#  ('carta', 'rain', 4),
#  ('carta', 'taiko', 4),
#  ('carta', 'west', 4),
#  ('carta', 'yama', 4),
#  ('carta', 'zarela', 4),
#  ("cassell's", "camille's", 4),
#  ('cassis', 'canoe', 4),
#  ('cassis', 'carta', 4),
#  ('cassis', 'cava', 4),
#  ('cassis', 'chevys', 4),
#  ('cassis', "chin's", 4),
#  ('cassis', 'citrus', 4),
#  ('cassis', 'eats', 4),
#  ('cassis', "harris'", 4),
#  ('cassis', "jack's", 4),
#  ('cassis', 'joss', 4),
#  ('cassis', 'katsu', 4),
#  ('cassis', 'patria', 4),
#  ('cassis', "paty's", 4),
#  ('cassis', 'pisces', 4),
#  ('cava', '2223', 4),
#  ('cava', 'aja', 4),
#  ('cava', 'bix', 4),
#  ('cava', 'bolo', 4),
#  ('cava', 'cassis', 4),
#  ('cava', 'chops', 4),
#  ('cava', 'dive!', 4),
#  ('cava', 'home', 4),
#  ('cava', 'joss', 4),
#  ('cava', 'katsu', 4),
#  ('cava', 'kiev', 4),
#  ('cava', 'layla', 4),
#  ('cava', 'lulu', 4),
#  ('cava', 'march', 4),
#  ('cava', "masa's", 4),
#  ('cava', 'match', 4),
#  ('cava', 'nobu', 4),
#  ('cava', 'orso', 4),
#  ('cava', 'palio', 4),
#  ('cava', 'pamir', 4),
#  ('cava', 'r-23', 4),
#  ('cava', "rae's", 4),
#  ('cava', 'remi', 4),
#  ('cava', 'shaan', 4),
#  ('cava', 'sofi', 4),
#  ('cava', 'soto', 4),
#  ('cava', 'taiko', 4),
#  ('cava', 'vong', 4),
#  ('cava', 'west', 4),
#  ('cava', 'zoe', 4),
#  ('chevys', 'cassis', 4),
#  ('chevys', 'chiam', 4),
#  ('chevys', 'chops', 4),
#  ('chevys', 'citrus', 4),
#  ('chevys', 'greens', 4),
#  ('chevys', 'kiev', 4),
#  ('chevys', 'thepin', 4),
#  ('chiam', 'aqua', 4),
#  ('chiam', 'c3', 4),
#  ('chiam', 'canoe', 4),
#  ('chiam', 'carta', 4),
#  ('chiam', 'chevys', 4),
#  ('chiam', 'cite', 4),
#  ('chiam', 'ct', 4),
#  ('chiam', 'dawat', 4),
#  ('chiam', 'diva', 4),
#  ('chiam', 'ebisu', 4),
#  ('chiam', 'lola', 4),
#  ('chiam', 'nava', 4),
#  ('chiam', 'rain', 4),
#  ('chiam', 'taiko', 4),
#  ('chiam', 'vida', 4),
#  ('chiam', 'yama', 4),
#  ("chin's", "bone's", 4),
#  ("chin's", 'cassis', 4),
#  ("chin's", 'chops', 4),
#  ("chin's", 'citrus', 4),
#  ("chin's", "drai's", 4),
#  ("chin's", "duke's", 4),
#  ("chin's", "jack's", 4),
#  ("chin's", "masa's", 4),
#  ("chin's", "paty's", 4),
#  ("chin's", 'rain', 4),
#  ("chin's", 'shiro', 4),
#  ('chops', 'c3', 4),
#  ('chops', 'canoe', 4),
#  ('chops', 'carta', 4),
#  ('chops', 'cava', 4),
#  ('chops', 'chevys', 4),
#  ('chops', "chin's", 4),
#  ('chops', 'cite', 4),
#  ('chops', 'ct', 4),
#  ('chops', 'docks', 4),
#  ('chops', "joe's", 4),
#  ('chops', "rae's", 4),
#  ('chops', 'shaan', 4),
#  ('chops', 'shiro', 4),
#  ('chops', 'stars', 4),
#  ('chops', 'thepin', 4),
#  ('cite', '2223', 4),
#  ('cite', 'abbey', 4),
#  ('cite', 'aja', 4),
#  ('cite', 'aqua', 4),
#  ('cite', 'bizou', 4),
#  ('cite', 'bolo', 4),
#  ('cite', 'canoe', 4),
#  ('cite', 'carta', 4),
#  ('cite', 'chiam', 4),
#  ('cite', 'chops', 4),
#  ('cite', 'faz', 4),
#  ('cite', 'first', 4),
#  ('cite', 'joss', 4),
#  ('cite', 'katsu', 4),
#  ('cite', 'lola', 4),
#  ('cite', 'lulu', 4),
#  ('cite', 'lutece', 4),
#  ('cite', 'match', 4),
#  ('cite', 'nava', 4),
#  ('cite', 'nobu', 4),
#  ('cite', 'orso', 4),
#  ('cite', 'palm', 4),
#  ('cite', 'r-23', 4),
#  ('cite', 'rain', 4),
#  ('cite', 'remi', 4),
#  ('cite', 'sofi', 4),
#  ('cite', 'vong', 4),
#  ('cite', 'west', 4),
#  ('cite', 'yama', 4),
#  ...]

# %%
import textdistance as td

def get_close(series):
    u = series.unique()
    u.sort()
    lu = [(p1, p2, p1 == p2 and 666 or td.hamming(p1, p2)) for p1 in u for p2 in u]
    nlu = list(filter(lambda x: x[2] > 0 and x[2] < 5, lu))
    nlu.sort(key = lambda x: x[2])
    return nlu

# %%
locateddata = data.copy()
locateddata

import googlemaps
gmaps = googlemaps.Client(key="AIzaSyCSxNRPj6sYgr9hTwepZdhz0PPMC_tpZtc")

def dogeocode(str):
    #return gmaps.geocode(str)
    return "lol      " + str

addresses = locateddata.address.unique()
wow = {}
for a in addresses:
    wow[a] = dogeocode(a)
    
#locateddata["geocode"] = locateddata.address.map(lambda x: wow[x])
#locateddata.to_csv(r'/data/restaurants_geocoded.csv')

# %%
locdata = pd.read_csv('/data/restaurants_geocoded.csv')
locdata
# Out:
#       id                           name                  address  \
# 0      1      arnie morton's of chicago   435 s. la cienega blv.
# 1      2      arnie morton's of chicago  435 s. la cienega blvd.
# 2      3             art's delicatessen      12224 ventura blvd.
# 3      4                     art's deli      12224 ventura blvd.
# 4      5                  hotel bel-air     701 stone canyon rd.
# ..   ...                            ...                      ...
# 859  860                        ti couz            3108 16th st.
# 860  861                      trio cafe        1870 fillmore st.
# 861  862                         tu lan              8 sixth st.
# 862  863                vicolo pizzeria              201 ivy st.
# 863  864  wa-ha-ka oaxaca mexican grill            2141 polk st.
#
#               city         phone         type  \
# 0      los angeles  310/246-1501     american
# 1      los angeles  310-246-1501  steakhouses
# 2      studio city  818/762-1221     american
# 3      studio city  818-762-1221        delis
# 4          bel air  310/472-1211  californian
# ..             ...           ...          ...
# 859  san francisco  415-252-7373       french
# 860  san francisco  415-563-2248     american
# 861  san francisco  415-626-0927   vietnamese
# 862  san francisco  415-863-2382        pizza
# 863  san francisco  415-775-1055      mexican
#
#                                         google_geocode
# 0    [{"address_components": [{"long_name": "435", ...
# 1    [{"address_components": [{"long_name": "435", ...
# 2    [{"address_components": [{"long_name": "12224"...
# 3    [{"address_components": [{"long_name": "12224"...
# 4    [{"address_components": [{"long_name": "701", ...
# ..                                                 ...
# 859  [{"address_components": [{"long_name": "3108",...
# 860  [{"address_components": [{"long_name": "1870",...
# 861  [{"address_components": [{"long_name": "8", "s...
# 862  [{"address_components": [{"long_name": "201", ...
# 863  [{"address_components": [{"long_name": "2141",...
#
# [864 rows x 7 columns]

# %%
locdata[locdata["geocode"] == "[]"]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /opt/conda/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2896             try:
# -> 2897                 return self._engine.get_loc(key)
#    2898             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'geocode'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-11-7a0abb04aee2> in <module>
# ----> 1 locdata[locdata["geocode"] == "[]"]
#
# /opt/conda/lib/python3.7/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2993             if self.columns.nlevels > 1:
#    2994                 return self._getitem_multilevel(key)
# -> 2995             indexer = self.columns.get_loc(key)
#    2996             if is_integer(indexer):
#    2997                 indexer = [indexer]
#
# /opt/conda/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2897                 return self._engine.get_loc(key)
#    2898             except KeyError:
# -> 2899                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2900         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#    2901         if indexer.ndim > 1 or indexer.size > 1:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'geocode'

# %%
def calcnew(x):
    if x.geocode == "[]":
        return str(gmaps.geocode(x["address"] + ", " + x["city"]))
    return x.geocode

locdata.geocode = locdata.apply(calcnew, axis=1)
#locateddata.to_csv(r'/data/restaurants_geocoded.csv')

# %%
#pd.read_json(locdata.loc[0].geocode, orient="index")
import re
import json

def load_dirty_json(dirty_json):
    regex_replace = [(r"([ \{,:\[])(u)?'([^']*)'", r'\1"\3"'), (r" False([, \}\]])", r' false\1'), (r" True([, \}\]])", r' true\1')]
    for r, s in regex_replace:
        dirty_json = re.sub(r, s, dirty_json)
    try:
        clean_json = json.loads(dirty_json)
    except:
        print(dirty_json)
        raise TypeError("Only integers are allowed")
    return clean_json

load_dirty_json(locdata.loc[0].geocode)[0]

# %%
locdata["lat"] = 0
locdata["lng"] = 0

def getloc(x, t):
    if x == "[]":
        return -1
    return load_dirty_json(x)[0]["geometry"]["location"][t]

def getplaceid(x):
    if x == "[]" or len(x) == 0:
        return -1
    return load_dirty_json(x)[0]["place_id"]

locdata["lat"] = locdata.geocode.map(lambda x: getloc(x, "lat"))
locdata["lng"] = locdata.geocode.map(lambda x: getloc(x, "lng"))
locdata["place_id"] = locdata.geocode.map(lambda x: getplaceid(x))

# %%
#locdata.to_csv(r'/data/restaurants_geocoded2.csv')
locdata

# %%
locdata.groupby(["place_id"]).count()
# goal here is 752 rows

# %%
# find out what to do about the bar anise
locdata[locdata["phone"].str.startswith("212")]

# %%
cleandata = data.copy()
cleandata = cleandata.drop(labels=['id'], axis=1)
cleandata.name = cleandata.name.str.replace('[^a-zA-Z0-9 ]', '', case=False)
cleandata.address = cleandata.address.str.replace('[^a-zA-Z0-9 ]', '', case=False)
cleandata.phone = cleandata.phone.str.replace('[^a-zA-Z0-9]', '', case=False)
cleandata.city = cleandata.city.str.replace('new york city', 'new york', case=False)
cleandata.type = cleandata.type.str.replace(' \(new\)', '', case=False)
#cleandata.city = cleandata.city.str.replace('studio city', 'los angeles', case=False)

cleandata = cleandata.drop_duplicates()
cleandata = cleandata.groupby(['name', 'address', 'city', 'phone'])["type"].apply(list).reset_index()
cleandata

# %% [markdown]
# Finding dirty data!

# %%
cleandata[cleandata.phone.str.match("^[0-9]{1,9}$")]

# %%
cleandata[cleandata.duplicated(['address'], keep=False)]

# %%
cleandata[cleandata["city"] == "w. hollywood"]
