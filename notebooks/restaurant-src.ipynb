# %% [markdown]
# # Helpful Links
# * https://www.dataquest.io/blog/jupyter-notebook-tips-tricks-shortcuts/

# %%
# %load ../src/clean.py
from src.clean import *

# %%
dupesets, dupeids = loadGoldStandard()

# %%
df = pd.read_csv(PATH_PREFIX + '/restaurants.tsv', delimiter='\t')
cleaned = clean(df, 0.7, 0.65)
a, b, c = compareToGold(cleaned, dupesets)
missingIds = [y for x in b for y in x]
falseIds = [y for x in c for y in x]
# Out:
# True positives: 106
# False negatives: 6
# False positives: 0
# Precision: 1.0
# Recall: 0.9464285714285714
# Fscore: 0.9724770642201834

# %%
cc = cleaned.copy()
cc.city = cc.city.map(lambda x: next(iter(x)))
cc = cc.groupby(["city", "tdkey"]).agg(list).reset_index()
cc
# Out:
#                                    city                   tdkey  \
# 0                      atlos angelesnta                103 west
# 1                      atlos angelesnta                   abbey
# 2                      atlos angelesnta                 abruzzi
# 3                      atlos angelesnta     adrianos ristorante
# 4                      atlos angelesnta  alecks barbecue heaven
# ..                                  ...                     ...
# 588                      west hollywood                   dukes
# 589  westlos angeleske villos angelesge                     aja
# 590  westlos angeleske villos angelesge            local nochol
# 591                            westwood                antonios
# 592                            westwood            falafel king
#
#                                                  phone  \
# 0                                         [4042335993]
# 1                                         [4048768532]
# 2                                         [4042618186]
# 3    [4042372663, 4042372700, 4042377601, 404261701...
# 4                                         [4045252062]
# ..                                                 ...
# 588                                       [3106523100]
# 589                                       [8054984049]
# 590                                       [8187067706]
# 591                                       [3102091422]
# 592                                       [3102084444]
#
#                                                     id  \
# 0                                              [{787}]
# 1                                              [{492}]
# 2                                         [{149, 150}]
# 3    [{153, 154}, {181, 182}, {831}, {793}, {496}, ...
# 4                                              [{493}]
# ..                                                 ...
# 588                                            [{663}]
# 589                                            [{648}]
# 590                                            [{684}]
# 591                                            [{662}]
# 592                                            [{664}]
#
#                                                   name  \
# 0                                         [{103 west}]
# 1                                            [{abbey}]
# 2                                          [{abruzzi}]
# 3    [{bone's restaurant, bone's}, {dining room  ri...
# 4                          [{aleck's barbecue heaven}]
# ..                                                 ...
# 588                                         [{duke's}]
# 589                                     [{baja fresh}]
# 590                                   [{local nochol}]
# 591                                  [{don antonio's}]
# 592                                   [{falafel king}]
#
#                                                address  \
# 0                           [{103 w. paces ferry rd.}]
# 1                           [{163 ponce de leon ave.}]
# 2    [{2355 peachtree rd. ne, 2355 peachtree rd.  p...
# 3    [{3130 piedmont road, 3130 piedmont rd. ne}, {...
# 4                   [{783 martin luther king jr. dr.}]
# ..                                                 ...
# 588                              [{8909 sunset blvd.}]
# 589                                [{3345 kimber dr.}]
# 590                      [{30869 thousand oaks blvd.}]
# 591                            [{1136 westwood blvd.}]
# 592                              [{1059 broxton ave.}]
#
#                                                   type  \
# 0                                      [{continental}]
# 1                                    [{international}]
# 2                                          [{italian}]
# 3    [{american, steakhouses}, {american, internati...
# 4                                         [{barbecue}]
# ..                                                 ...
# 588                                   [{coffee shops}]
# 589                                        [{mexican}]
# 590                                    [{health food}]
# 591                                        [{italian}]
# 592                                 [{middle eastern}]
#
#                                                  cname  \
# 0                                         [{103 west}]
# 1                                            [{abbey}]
# 2                                          [{abruzzi}]
# 3    [{bones, bones restaurant}, {dining room  ritz...
# 4                           [{alecks barbecue heaven}]
# ..                                                 ...
# 588                                          [{dukes}]
# 589                                     [{baja fresh}]
# 590                                   [{local nochol}]
# 591                                   [{don antonios}]
# 592                                   [{falafel king}]
#
#                                               caddress
# 0                             [{103 w paces ferry rd}]
# 1                            [{163 ponce de leon ave}]
# 2    [{2355 peachtree rd ne, 2355 peachtree rd  pea...
# 3    [{3130 piedmont rd ne, 3130 piedmont road}, {3...
# 4                     [{783 martin luther king jr dr}]
# ..                                                 ...
# 588                               [{8909 sunset blvd}]
# 589                                 [{3345 kimber dr}]
# 590                       [{30869 thousand oaks blvd}]
# 591                             [{1136 westwood blvd}]
# 592                               [{1059 broxton ave}]
#
# [593 rows x 9 columns]

# %%
print(missingIds)
print(falseIds)
# Out:
# [121, 122, 129, 130, 139, 140, 141, 142, 144, 143, 179, 180]
# []

# %%
#df[df.id.isin(missingIds)]
df[df.id.isin(missingIds)]
# Out:
#       id                          name                 address  \
# 120  121                 shun lee west          43 w. 65th st.
# 121  122               shun lee palace         155 e. 55th st.
# 128  129                  uncle nick's           747 9th ave.
# 129  130                  uncle nick's          747 ninth ave.
# 138  139                 le montrachet    3000 w. paradise rd.
# 139  140          le montrachet bistro       3000 paradise rd.
# 140  141                  palace court  3570 las vegas blvd. s
# 141  142                  palace court  3570 las vegas blvd. s
# 142  143          second street grille      200 e. fremont st.
# 143  144           second street grill      200 e. fremont st.
# 178  179  cafe  ritz-carlton  buckhead      3434 peachtree rd.
# 179  180             ritz-carlton cafe   3434 peachtree rd. ne
#
#                    city       phone           type  \
# 120            new york  2123718844          asian
# 121            new york  2123718844        chinese
# 128            new york  2123151726  mediterranean
# 129            new york  2122457992          greek
# 138  los angeless vegas  7027325111    continental
# 139  los angeless vegas  7027325651  french bistro
# 140  los angeless vegas  7027317547    continental
# 141  los angeless vegas  7027317110         french
# 142  los angeless vegas  7023853232        seafood
# 143  los angeless vegas  7023856277    pacific rim
# 178    atlos angelesnta  4042372700  international
# 179    atlos angelesnta  4042372700       american
#
#                            cname               caddress  \
# 120                shun lee west           43 w 65th st
# 121              shun lee palace          155 e 55th st
# 128                  uncle nicks           747 9th ave
# 129                  uncle nicks          747 ninth ave
# 138                le montrachet     3000 w paradise rd
# 139         le montrachet bistro       3000 paradise rd
# 140                 palace court  3570 las vegas blvd s
# 141                 palace court  3570 las vegas blvd s
# 142         second street grille       200 e fremont st
# 143          second street grill       200 e fremont st
# 178  cafe  ritzcarlton  buckhead      3434 peachtree rd
# 179             ritzcarlton cafe   3434 peachtree rd ne
#
#                            tdkey
# 120                     103 west
# 121              shun lee palace
# 128                  uncle nicks
# 129                  uncle nicks
# 138         alons at the terrace
# 139         alons at the terrace
# 140                campton place
# 141                campton place
# 142             ambassador grill
# 143             ambassador grill
# 178  cafe  ritzcarlton  buckhead
# 179             ritzcarlton cafe

# %%
cleaned
# Out:
#           phone                 tdkey         id                 name  \
# 0    1008138212       indian delights      {809}    {indian delights}
# 1    2122060059               big cup      {301}            {big cup}
# 2    2122132288   marnies noodle shop      {751}  {sam's noodle shop}
# 3    2122190500              bouterin      {743}               {nobu}
# 4    2122192777  alons at the terrace  {99, 100}         {montrachet}
# ..          ...                   ...        ...                  ...
# 753  8188865679      ambassador grill      {653}       {brent's deli}
# 754  8189056515  alons at the terrace      {702}   {rubin's red hots}
# 755  8189068881           mulberry st      {692}       {mulberry st.}
# 756  8189854669             cadel sol      {232}         {ca'del sol}
# 757  8189900500  alons at the terrace   {37, 38}       {pinot bistro}
#
#                                  address           city  \
# 0                 {3675 satellite blvd.}             {}
# 1                        {228 8th ave. }             {}
# 2                       {411 third ave.}             {}
# 3                       {105 hudson st.}             {}
# 4    {239 w. broadway, 239 w. broadway }             {}
# ..                                   ...            ...
# 753               {19565 parthenia ave.}             {}
# 754                {15322 ventura blvd.}             {}
# 755                {17040 ventura blvd.}             {}
# 756                {4100 cahuenga blvd.}             {}
# 757                {12969 ventura blvd.}  {studio city}
#
#                         type               cname  \
# 0                   {indian}   {indian delights}
# 1               {coffee bar}           {big cup}
# 2                  {chinese}  {sams noodle shop}
# 3                 {japanese}              {nobu}
# 4    {french bistro, french}        {montrachet}
# ..                       ...                 ...
# 753                  {delis}       {brents deli}
# 754               {hot dogs}   {rubins red hots}
# 755                  {pizza}       {mulberry st}
# 756                {italian}         {cadel sol}
# 757  {french bistro, french}      {pinot bistro}
#
#                               caddress
# 0                {3675 satellite blvd}
# 1                       {228 8th ave }
# 2                      {411 third ave}
# 3                      {105 hudson st}
# 4    {239 w broadway, 239 w broadway }
# ..                                 ...
# 753              {19565 parthenia ave}
# 754               {15322 ventura blvd}
# 755               {17040 ventura blvd}
# 756               {4100 cahuenga blvd}
# 757               {12969 ventura blvd}
#
# [758 rows x 9 columns]
