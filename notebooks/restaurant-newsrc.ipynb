# %%
# %cd /src
# %run 'utils.py'
import utils
# Out:
# /src

# %%
# %run -i -t '/src/main.py'
# Out:
# tp,tn,fp,fn,precision,recall,fscore
# 224,640,0,0,1.0,1.0,1.0
# Written two jsons 'deduped_raw.json' and 'deduped_clean.json' to directory '/data/work'.
# You can use those with mongoimport!
#
# IPython CPU timings (estimated):
#   User   :       4.43 s.
#   System :       0.00 s.
# Wall time:       4.44 s.

# %%
cleaned
# Out:
#              id                                    name            address  \
# 0         {864}           wa-ha-ka oaxaca mexican grill      2141 polk st.
# 1         {863}                         vicolo pizzeria        201 ivy st.
# 2         {862}                                  tu lan        8 sixth st.
# 3         {861}                               trio cafe  1870 fillmore st.
# 4         {860}                                 ti couz      3108 16th st.
# ..          ...                                     ...                ...
# 747  {216, 215}  mifune japan center  kintetsu building      1737 post st.
# 748  {217, 218}                          plumpjack cafe  3127 fillmore st.
# 749  {219, 220}                                 postrio       545 post st.
# 750  {221, 222}                ritz-carlton dining room   600 stockton st.
# 751  {224, 223}                            rose pistola  532 columbus ave.
#
#               city         phone                       type  \
# ...
