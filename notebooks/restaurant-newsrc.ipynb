# %%
# %run -i '/src/utils.py'
import utils as utils
utils.PATH_PREFIX = "/data"

# %%
# %run -i '/src/new_clean.py'
# Out:
# Real duplicates:  [{1, 2}, {3, 4}, {5, 6}, {8, 7}, {9, 10}, {11, 12}, {13, 14}, {16, 15}, {17, 18}, {19, 20}, {21, 22}, {24, 23}, {25, 26}, {27, 28}, {29, 30}, {32, 31}, {33, 34}, {35, 36}, {37, 38}, {40, 39}, {41, 42}, {43, 44}, {45, 46}, {48, 47}, {49, 50}, {51, 52}, {53, 54}, {56, 55}, {57, 58}, {59, 60}, {61, 62}, {64, 63}, {65, 66}, {67, 68}, {69, 70}, {72, 71}, {73, 74}, {75, 76}, {77, 78}, {80, 79}, {81, 82}, {83, 84}, {85, 86}, {88, 87}, {89, 90}, {91, 92}, {93, 94}, {96, 95}, {97, 98}, {99, 100}, {101, 102}, {104, 103}, {105, 106}, {107, 108}, {109, 110}, {112, 111}, {113, 114}, {115, 116}, {117, 118}, {120, 119}, {121, 122}, {123, 124}, {125, 126}, {128, 127}, {129, 130}, {131, 132}, {133, 134}, {136, 135}, {137, 138}, {139, 140}, {141, 142}, {144, 143}, {145, 146}, {147, 148}, {149, 150}, {152, 151}, {153, 154}, {155, 156}, {157, 158}, {160, 159}, {161, 162}, {163, 164}, {165, 166}, {168, 167}, {169, 170}, {171, 172}, {173, 174}, {176, 175}, {177, 178}, {179, 180}, {181, 1
# ...

# %%
cleaned
# Out:
#      group          id                                               name  \
# 0     -864       {864}                    {wa-ha-ka oaxaca mexican grill}
# 1     -863       {863}                                  {vicolo pizzeria}
# 2     -862       {862}                                           {tu lan}
# 3     -861       {861}                                        {trio cafe}
# 4     -860       {860}                                          {ti couz}
# ..     ...         ...                                                ...
# 747    107  {216, 215}   {mifune japan center  kintetsu building, mifune}
# 748    108  {217, 218}                                   {plumpjack cafe}
# 749    109  {219, 220}                                          {postrio}
# 750    110  {221, 222}  {ritz-carlton restaurant and dining room, ritz...
# 751    111  {224, 223}                                     {rose pistola}
#
#                                     address             city         phone  \
# ...
